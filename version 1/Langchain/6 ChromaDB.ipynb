# %%
from langchain_chroma import Chroma

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import OllamaEmbeddings

# %%
loader=TextLoader("Data_Ingestion.txt")

# %%
data=loader.load()

# %%
ollama_embedding=OllamaEmbeddings(model="nomic-embed-text")

# %%
text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=0)
splits=text_splitter.split_documents(data)

# %%
vectordb=Chroma.from_documents(documents=splits,embedding=ollama_embedding)

# %%
query="Can you summarize the documents in 3 points?"

# %%
vectordb=Chroma(embedding_function=ollama_embedding)

# %%
query_result=vectordb.similarity_search(query)

# %%
query_result[0].page_content
# Out:
# "2. Sustainable Energy: \nAI algorithms are now managing smart grids in major cities. These systems predict energy spikes and redistribute electricity from renewable sources like solar and wind efficiently, reducing carbon emissions by 30% compared to 2020.\n\n3. Education and Learning: \nThe concept of 'Universal Classrooms' has emerged. AI tutors provide 1:1 mentorship to students in their native languages, including Bengali, making high-quality education accessible in rural areas."

# %%
retriever=vectordb.as_retriever()

# %%
retriever.invoke(query)[0].page_content
# Out:
# "2. Sustainable Energy: \nAI algorithms are now managing smart grids in major cities. These systems predict energy spikes and redistribute electricity from renewable sources like solar and wind efficiently, reducing carbon emissions by 30% compared to 2020.\n\n3. Education and Learning: \nThe concept of 'Universal Classrooms' has emerged. AI tutors provide 1:1 mentorship to students in their native languages, including Bengali, making high-quality education accessible in rural areas."

# %%
vec
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 vec
#
# NameError: name 'vec' is not defined
