# %%
from langchain.agents import create_agent
from pydantic import Field,BaseModel
from langchain_ollama import ChatOllama
from dataclasses import dataclass

# %%
model=ChatOllama(model="llama3.1:8b")

# %%
@dataclass
class ContactInfo(BaseModel):
    # """Contact information for a person"""
    name:str  #the name of the person
    email:str #the email address of the person
    phone:str #the phone number of the person

# %%
agent=create_agent(model,response_format=ContactInfo)

# %%
res=agent.invoke({"messages":[{"role":"user","content":"director of Avatar"}]})

# %%
res["structured_response"]
# Out:
# ContactInfo(name='James Cameron', email='james.cameron@20thcenturyfox.com', phone='(555) 123-4567')

# %%
agent
