# %%
from langchain.chat_models import init_chat_model

# %%
model=init_chat_model("ollama:phi4:latest")

# %% [markdown]
# ### Stream

# %%
for chunk in model.stream("Write me a 200 words paragraph on AI"):
    print(chunk.text,end=" ",flush=True)
# Out:
# Art ificial  Intelligence  ( AI )  is  rapidly  transforming  the  landscape  of  technology  and  society .  At  its  core ,  AI  aims  to  simulate  human  intelligence  processes  by  machines ,  particularly  computer  systems .  These  processes  include  learning ,  reasoning ,  problem -solving ,  perception ,  language  understanding ,  and  decision -making .  Over  recent  decades ,  advancements  in  machine  learning  algorithms  and  exponential  growth  in  computing  power  have  propelled  AI  from  theoretical  research  to  real -world  applications  across  various  sectors .  In  healthcare ,  AI  assists  in  diagn osing  diseases  with  precision  through  image  recognition  and  data  analysis ,  enhancing  both  accuracy  and  efficiency .  The  retail  industry  lever ages  AI  for  personalized  recommendations  and  efficient  inventory  management  by  analyzing  consumer  behavior  patterns .  Autonomous  vehicles  employ  AI  to  interpret  sensory  information  and  make  split -second  decisions  on  the  road ,  showcasing  its  potential  to  revolution ize  transportation .  However ,  these  advancements  also  bring  ethical  considerations  regarding  privacy ,  bias  in  decision -making  algorithms ,  and  job  displacement  due  to  automation .  As  AI  continues  to  evolve ,  it  holds  both  the  promise  of  enhancing  human  capabilities  and  addressing  complex  global  challenges ,  while  necess itating  robust  frameworks  for  governance  and  accountability .  The  future  of  AI  is  one  of  immense  potential  but  also  requires  careful  navigation  to  ensure  its  benefits  are  maxim ized  responsibly  and  equ itably  across  society .

# %% [markdown]
# ### Batch

# %%
responses=model.batch([
    "Why do parrots have colorful features?",
    "how do airplanes fly?",
    "What is quantum computing?"
],config={'max_concurrency':1})

for response in responses:
    print(response)
# Out:
# content='Parrots are known for their vibrant colors, which serve several purposes and result from a combination of evolutionary, ecological, and behavioral factors:\n\n1. **Sexual Selection**: Brightly colored feathers can be an indicator of health and genetic fitness. In many bird species, including parrots, females often choose mates based on the vibrancy of their plumage, associating brighter colors with better genes, good nutrition, and overall vitality.\n\n2. **Species Recognition**: Distinct color patterns help parrots identify members of their own species, which is crucial for social interactions, mating, and territorial behaviors. This ensures that they engage with conspecifics rather than other species, reducing the risk of unsuccessful mating attempts or conflicts.\n\n3. **Mate Attraction**: For many parrot species, males exhibit more vivid colors to attract females. These bright feathers can signal dominance, strength, or superior genes, which are desirable traits for offspring.\n\n4. **Camouflage and Safety**: While it might seem counterintuitive, some colorful features also help with camouflage. In the dense rainforests where many parrots live, their bright plumage often breaks up their outline against the vibrant background of foliage and flowers, helping them avoid predators.\n\n5. **Communication**: Colors can be used in social signaling among parrots. Different colors or patterns might indicate mood, readiness to mate, aggression, or submission within a group setting. This is especially important for highly social species that rely on visual cues.\n\n6. **UV Sensitivity and Pigmentation**: The vibrant colors of parrots are often due to structural coloration and pigments like carotenoids. Carotenoid-based colors depend on diet, as these birds cannot synthesize them internally; thus, they must be acquired from food sources such as fruits, seeds, and flowers.\n\n7. **Niche Adaptation**: Some parrot species have developed specific color patterns that suit their ecological niche. For instance, some ground-dwelling species might have colors that help blend into the soil or underbrush, while arboreal species display hues that match tree bark or leaves.\n\nOverall, the colorful features of parrots are a complex interplay of natural selection and social dynamics that enhance their survival and reproductive success in diverse environments.' additional_kwargs={} response_metadata={'model': 'phi4:latest', 'created_at': '2026-02-16T09:53:19.609024427Z', 'done': True, 'done_reason': 'stop', 'total_duration': 14241732019, 'load_duration': 46764528, 'prompt_eval_count': 18, 'prompt_eval_duration': 53769817, 'eval_count': 451, 'eval_duration': 13869632702, 'logprobs': None, 'model_name': 'phi4:latest', 'model_provider': 'ollama'} id='lc_run--019c65de-2d56-7811-a7dd-31359a987188-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 18, 'output_tokens': 451, 'total_tokens': 469}
# content="Airplanes fly based on the principles of aerodynamics, which involve the generation and manipulation of lift, thrust, drag, and weight. Here's a simplified explanation:\n\n1. **Lift**: This is the force that allows an airplane to rise into the air and stay aloft. Lift is generated primarily by the wings. The shape of the wing (airfoil) causes the air flowing over the top surface to move faster than the air below it, creating lower pressure on top according to Bernoulli's principle. Additionally, the angle at which the wing meets the oncoming air (angle of attack) contributes to lift through differences in air pressure above and below the wings. This differential in pressure produces an upward force.\n\n2. **Thrust**: Thrust is the forward force that propels an airplane through the air. It is generated by engines, such as jet engines or propellers. Jet engines work by expelling fast-moving exhaust gases backward, which pushes the plane forward (Newton’s third law of motion: for every action, there is an equal and opposite reaction). Propeller-driven aircraft use rotating blades to push air backward, generating a similar forward thrust.\n\n3. **Drag**: Drag is the resistance force that opposes the airplane's motion through the air. There are two main types: parasite drag (caused by the shape of the aircraft, surface roughness, etc.) and induced drag (a byproduct of lift). Pilots manage these forces to maintain efficient flight, often adjusting speed or wing configuration.\n\n4. **Weight**: Weight is the force due to gravity acting on the mass of the airplane. It acts downward, opposing lift. For an airplane to take off, lift must overcome weight. In steady, level flight, lift and weight are balanced. Similarly, thrust needs to overcome drag for sustained forward motion.\n\nTo achieve controlled flight, pilots manage these forces through adjustments in speed, engine power, wing configuration (such as flaps or slats), and control surfaces (ailerons, rudder, elevators). These actions allow the aircraft to climb, descend, turn, and maintain various attitudes during different phases of flight. \n\nOverall, an airplane's ability to fly is a delicate balance between these four forces, achieved through precise design and operation." additional_kwargs={} response_metadata={'model': 'phi4:latest', 'created_at': '2026-02-16T09:53:34.095407745Z', 'done': True, 'done_reason': 'stop', 'total_duration': 14485471429, 'load_duration': 52200408, 'prompt_eval_count': 15, 'prompt_eval_duration': 49519050, 'eval_count': 458, 'eval_duration': 14130756511, 'logprobs': None, 'model_name': 'phi4:latest', 'model_provider': 'ollama'} id='lc_run--019c65de-64f9-7a22-8804-f3e60c22899a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 458, 'total_tokens': 473}
# content="Quantum computing is an advanced computational paradigm that leverages the principles of quantum mechanics to process information in fundamentally different ways than classical computers. Here's a breakdown of its key concepts:\n\n1. **Qubits**: Unlike classical bits, which are binary and can be either 0 or 1, qubits (quantum bits) can exist in a state known as superposition. This means they can represent both 0 and 1 simultaneously, allowing quantum computers to handle vastly more information with the same number of particles.\n\n2. **Entanglement**: Qubits can become entangled, meaning the state of one qubit is directly related to the state of another, no matter the distance between them. This property allows for complex correlations that can be exploited in computational processes to solve problems faster than classical computers.\n\n3. **Quantum Gates**: Quantum computations are performed using quantum gates, which manipulate qubits through operations analogous to logical gates in classical computing but based on unitary transformations. These gates change the state of qubits and allow for the creation of quantum algorithms.\n\n4. **Quantum Algorithms**: Certain problems can be more efficiently solved by quantum computers than classical ones due to specific quantum algorithms like Shor's algorithm (for factoring large numbers) and Grover's algorithm (for searching unsorted databases). These algorithms take advantage of superposition, entanglement, and interference to perform calculations in ways that are currently beyond the reach of classical computing.\n\n5. **Quantum Interference**: This principle allows quantum systems to amplify correct paths or solutions while canceling out incorrect ones. It is crucial for the functioning of many quantum algorithms, helping guide computations towards the desired outcome.\n\n6. **Challenges and Limitations**: Quantum computers face significant technical challenges such as error rates, qubit decoherence (loss of quantum state), and scalability. Current quantum devices are often referred to as Noisy Intermediate-Scale Quantum (NISQ) devices due to these limitations. Researchers are actively working on developing error correction techniques and more stable qubits.\n\n7. **Applications**: Potential applications of quantum computing include cryptography, complex simulations in chemistry and materials science, optimization problems, machine learning enhancements, and other areas where classical computers struggle with computational complexity or resource requirements.\n\nQuantum computing is still an emerging field, but it holds the promise of revolutionizing many industries by solving certain types of problems much more efficiently than traditional computers." additional_kwargs={} response_metadata={'model': 'phi4:latest', 'created_at': '2026-02-16T09:53:49.455267632Z', 'done': True, 'done_reason': 'stop', 'total_duration': 15358822718, 'load_duration': 49596547, 'prompt_eval_count': 15, 'prompt_eval_duration': 49070306, 'eval_count': 485, 'eval_duration': 14983296113, 'logprobs': None, 'model_name': 'phi4:latest', 'model_provider': 'ollama'} id='lc_run--019c65de-9d90-7cc3-a5ec-31419e17072e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 485, 'total_tokens': 500}
