# %%
from nltk.tokenize import sent_tokenize

# %%
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/workstation-p/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
corpus="""
Hello, Welcome to GenAI's Part!!!. Basically corpus means paragraph.
"""

# %%
corpus
# Out:
# "\nHello, Welcome to GenAI's Part!!!. Basically corpus means paragraph.\n"

# %%
print(corpus)
# Out:
# Hello, Welcome to GenAI's Part!!!. Basically corpus means paragraph.

# %%
display(corpus)
# Out:
# "\nHello, Welcome to GenAI's Part!!!. Basically corpus means paragraph.\n"

# %%
sent_tokenize(corpus,language="english")
# Out:
# ["\nHello, Welcome to GenAI's Part!!!.", 'Basically corpus means paragraph.']

# %%
for sentence in sent_tokenize(corpus):
    print(sentence)
# Out:
# Hello, Welcome to GenAI's Part!!!.
# Basically corpus means paragraph.

# %% [markdown]
# ### Paragraph into words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'to',
#  'GenAI',
#  "'s",
#  'Part',
#  '!',
#  '!',
#  '!',
#  '.',
#  'Basically',
#  'corpus',
#  'means',
#  'paragraph',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'to',
#  'GenAI',
#  "'",
#  's',
#  'Part',
#  '!!!.',
#  'Basically',
#  'corpus',
#  'means',
#  'paragraph',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'to',
#  'GenAI',
#  "'s",
#  'Part',
#  '!',
#  '!',
#  '!',
#  '.',
#  'Basically',
#  'corpus',
#  'means',
#  'paragraph',
#  '.']
