# %%
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK,Trials,fmin,hp,tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import mlflow
from mlflow.models import infer_signature
# Out:
# /home/test-14900/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
from tensorflow import keras
# Out:
# 2026-01-24 05:43:28.582162: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-24 05:43:28.692472: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-24 05:43:29.552119: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
df=pd.read_csv("https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",sep=";")

# %%
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df.isna().value_counts()
# Out:
# fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  density  pH     sulphates  alcohol  quality
# False          False             False        False           False      False                False                 False    False  False      False    False      4898
# Name: count, dtype: int64

# %%
df.isnull().value_counts()
# Out:
# fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  density  pH     sulphates  alcohol  quality
# False          False             False        False           False      False                False                 False    False  False      False    False      4898
# Name: count, dtype: int64

# %%
df.describe().T
# Out:
#                        count        mean        std      min         25%  \
# fixed acidity         4898.0    6.854788   0.843868  3.80000    6.300000
# volatile acidity      4898.0    0.278241   0.100795  0.08000    0.210000
# citric acid           4898.0    0.334192   0.121020  0.00000    0.270000
# residual sugar        4898.0    6.391415   5.072058  0.60000    1.700000
# chlorides             4898.0    0.045772   0.021848  0.00900    0.036000
# free sulfur dioxide   4898.0   35.308085  17.007137  2.00000   23.000000
# total sulfur dioxide  4898.0  138.360657  42.498065  9.00000  108.000000
# density               4898.0    0.994027   0.002991  0.98711    0.991723
# pH                    4898.0    3.188267   0.151001  2.72000    3.090000
# sulphates             4898.0    0.489847   0.114126  0.22000    0.410000
# alcohol               4898.0   10.514267   1.230621  8.00000    9.500000
# quality               4898.0    5.877909   0.885639  3.00000    5.000000
#
#                             50%       75%        max
# fixed acidity           6.80000    7.3000   14.20000
# volatile acidity        0.26000    0.3200    1.10000
# citric acid             0.32000    0.3900    1.66000
# residual sugar          5.20000    9.9000   65.80000
# chlorides               0.04300    0.0500    0.34600
# free sulfur dioxide    34.00000   46.0000  289.00000
# total sulfur dioxide  134.00000  167.0000  440.00000
# density                 0.99374    0.9961    1.03898
# pH                      3.18000    3.2800    3.82000
# sulphates               0.47000    0.5500    1.08000
# alcohol                10.40000   11.4000   14.20000
# quality                 6.00000    6.0000    9.00000

# %%
quality=df['quality']
display(quality)
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %%
df.drop(columns='quality',axis=1)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol
# 0         8.8
# 1         9.5
# 2        10.1
# 3         9.9
# 4         9.9
# ...       ...
# 4893     11.2
# 4894      9.6
# 4895      9.4
# 4896     12.8
# 4897     11.8
#
# [4898 rows x 11 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(df,quality,test_size=0.25,random_state=45)

# %%
signature=infer_signature(X_train.to_numpy(),y_train)
# Out:
# /home/test-14900/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/mlflow/types/utils.py:407: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(

# %%
### ANN
def train_model(parameters,epochs,train_x,train_y,test_x,test_y):
    ## model architecture
    mean=np.mean(test_x,axis=0)
    var=np.var(test_x,axis=0)
    model=keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean,variance=var),
            keras.layers.Dense(64,activation="relu"),
            keras.layers.Dense(1)
								]
				)
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=parameters["lr"],momentum=parameters["momentum"]
				),
                loss="mean_squared_error",
    metrics=[keras.metrics.RootMeanSquaredError()]
    
				)
    with mlflow.start_run(nested=True):
            model.fit(train_x,train_y,validation_data=(test_x,test_y),epochs=epochs,batch_size=64)
            eval_result=model.evaluate(test_x,test_y,batch_size=64)
            eval_rmse=eval_result[1]
            mlflow.log_params(params=parameters)
            mlflow.log_metric("eval_rmse",eval_rmse)
            mlflow.tensorflow.log_model(model,"model",signature=signature)
            return {"loss":eval_rmse,"status":STATUS_OK,"model":model}

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
def objective(params):
    result=train_model(params,50,X_train,y_train,X_test,y_test)
    return result

# %%
space={
    "lr":hp.loguniform("lr",np.log(1e-5),np.log(1e-1)),
    "momentum":hp.uniform("momentum",0.0,1.0)
}

# %%
mlflow.set_experiment("ANN with mlflow")
with mlflow.start_run():
    # Conduct hyperparam search using Hyperopt
    trials=Trials()
    best=fmin(fn=objective,space=space,algo=tpe.suggest,max_evals=5,trials=trials)
    best_run=sorted(trials.results,key=lambda x:x["loss"])[0]
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse",best_run['loss'])
    mlflow.tensorflow.log_model(best_run["model"],"model",signature=signature)
# Out:
#   0%|          | 0/5 [00:00<?, ?trial/s, best loss=?]
# 2026-01-24 05:43:32.746615: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 11s 205ms/step - loss: 35.4452 - root_mean_squared_error: 5.9536
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5217 - root_mean_squared_error: 1.5880 - val_loss: 0.3826 - val_root_mean_squared_error: 0.6186
#
# Epoch 2/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4852 - root_mean_squared_error: 0.6966
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1641 - root_mean_squared_error: 0.4051 - val_loss: 0.1131 - val_root_mean_squared_error: 0.3363
#
# Epoch 3/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0674 - root_mean_squared_error: 0.2597
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0520 - root_mean_squared_error: 0.2280 - val_loss: 0.0487 - val_root_mean_squared_error: 0.2206
#
# Epoch 4/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0312 - root_mean_squared_error: 0.1766
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0231 - root_mean_squared_error: 0.1519 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1642
#
# Epoch 5/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0122 - root_mean_squared_error: 0.1103
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0139 - root_mean_squared_error: 0.1181 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1375
#
# Epoch 6/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0102 - root_mean_squared_error: 0.1010
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1210
#
# Epoch 7/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0074 - root_mean_squared_error: 0.0858
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0082 - root_mean_squared_error: 0.0903 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
#
# Epoch 8/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0067 - root_mean_squared_error: 0.0818 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1018
#
# Epoch 9/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0037 - root_mean_squared_error: 0.0609
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0059 - root_mean_squared_error: 0.0771 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0955
#
# Epoch 10/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0056 - root_mean_squared_error: 0.0748
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0052 - root_mean_squared_error: 0.0719 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0915
#
# Epoch 11/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0031 - root_mean_squared_error: 0.0560
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0047 - root_mean_squared_error: 0.0684 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
#
# Epoch 12/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0033 - root_mean_squared_error: 0.0576
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0834
#
# Epoch 13/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0039 - root_mean_squared_error: 0.0624 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0813
#
# Epoch 14/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0043 - root_mean_squared_error: 0.0654
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0036 - root_mean_squared_error: 0.0604 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0794
#
# Epoch 15/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0035 - root_mean_squared_error: 0.0589
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0034 - root_mean_squared_error: 0.0584 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0781
#
# Epoch 16/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0043 - root_mean_squared_error: 0.0655
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0032 - root_mean_squared_error: 0.0565 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0749
#
# Epoch 17/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0048 - root_mean_squared_error: 0.0692
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0030 - root_mean_squared_error: 0.0552 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0728
#
# Epoch 18/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0028 - root_mean_squared_error: 0.0528
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0029 - root_mean_squared_error: 0.0535 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0707
#
# Epoch 19/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - root_mean_squared_error: 0.0559
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0516 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
#
# Epoch 20/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0027 - root_mean_squared_error: 0.0523
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0507 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
#
# Epoch 21/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - root_mean_squared_error: 0.0523
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0025 - root_mean_squared_error: 0.0497 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
#
# Epoch 22/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0021 - root_mean_squared_error: 0.0462
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023 - root_mean_squared_error: 0.0480 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0649
#
# Epoch 23/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0019 - root_mean_squared_error: 0.0434
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022 - root_mean_squared_error: 0.0470 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0654
#
# Epoch 24/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0027 - root_mean_squared_error: 0.0520
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0021 - root_mean_squared_error: 0.0460 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0624
#
# Epoch 25/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - root_mean_squared_error: 0.0405
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020 - root_mean_squared_error: 0.0447 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0623
#
# Epoch 26/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020 - root_mean_squared_error: 0.0442 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
#
# Epoch 27/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - root_mean_squared_error: 0.0403
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019 - root_mean_squared_error: 0.0433 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0599
#
# Epoch 28/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - root_mean_squared_error: 0.0399
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018 - root_mean_squared_error: 0.0423 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0591
#
# Epoch 29/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - root_mean_squared_error: 0.0423
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017 - root_mean_squared_error: 0.0417 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0591
#
# Epoch 30/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - root_mean_squared_error: 0.0402
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017 - root_mean_squared_error: 0.0409 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0577
#
# Epoch 31/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - root_mean_squared_error: 0.0344
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - root_mean_squared_error: 0.0401 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0566
#
# Epoch 32/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - root_mean_squared_error: 0.0398 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0571
#
# Epoch 33/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - root_mean_squared_error: 0.0377
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - root_mean_squared_error: 0.0391 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0560
#
# Epoch 34/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.8324e-04 - root_mean_squared_error: 0.0297
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0549
#
# Epoch 35/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - root_mean_squared_error: 0.0406
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - root_mean_squared_error: 0.0380 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0545
#
# Epoch 36/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0013 - root_mean_squared_error: 0.0355
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - root_mean_squared_error: 0.0375 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0538
#
# Epoch 37/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0012 - root_mean_squared_error: 0.0351
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - root_mean_squared_error: 0.0370 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0535
#
# Epoch 38/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.4014e-04 - root_mean_squared_error: 0.0307
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - root_mean_squared_error: 0.0364 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0526
#
# Epoch 39/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0010 - root_mean_squared_error: 0.0318
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - root_mean_squared_error: 0.0360 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0528
#
# Epoch 40/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - root_mean_squared_error: 0.0355 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0523
#
# Epoch 41/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0023 - root_mean_squared_error: 0.0483
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - root_mean_squared_error: 0.0351 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0515
#
# Epoch 42/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.9269e-04 - root_mean_squared_error: 0.0315
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - root_mean_squared_error: 0.0346 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0515
#
# Epoch 43/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0011 - root_mean_squared_error: 0.0339
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - root_mean_squared_error: 0.0344 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0517
#
# Epoch 44/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.7752e-04 - root_mean_squared_error: 0.0313
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - root_mean_squared_error: 0.0340 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0505
#
# Epoch 45/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0011 - root_mean_squared_error: 0.0326
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - root_mean_squared_error: 0.0336 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0502
#
# Epoch 46/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - root_mean_squared_error: 0.0378
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - root_mean_squared_error: 0.0335 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0494
#
# Epoch 47/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.5541e-04 - root_mean_squared_error: 0.0275
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - root_mean_squared_error: 0.0329 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0497
#
# Epoch 48/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0010 - root_mean_squared_error: 0.0319
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - root_mean_squared_error: 0.0326 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0482
#
# Epoch 49/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.1219e-04 - root_mean_squared_error: 0.0285
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010 - root_mean_squared_error: 0.0323 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0485
#
# Epoch 50/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.5147e-04 - root_mean_squared_error: 0.0308
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010 - root_mean_squared_error: 0.0318 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0492
#
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - root_mean_squared_error: 0.0330
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 0.0024 - root_mean_squared_error: 0.0492
#
#   0%|          | 0/5 [00:05<?, ?trial/s, best loss=?]
# 2026/01/24 05:43:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run intelligent-roo-855 at: http://127.0.0.1:5000/#/experiments/306340854970463397/runs/451b40586bf5437cafb403f8f16f4414.
#
# 2026/01/24 05:43:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/306340854970463397.
# Epoch 1/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - loss: 33.8851 - root_mean_squared_error: 5.8211
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.3359 - root_mean_squared_error: 5.5078 - val_loss: 27.0281 - val_root_mean_squared_error: 5.1989
#
# Epoch 2/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 27.9151 - root_mean_squared_error: 5.2835
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 24.4961 - root_mean_squared_error: 4.9494 - val_loss: 21.8167 - val_root_mean_squared_error: 4.6708
#
# Epoch 3/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.7981 - root_mean_squared_error: 4.6688
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19.7180 - root_mean_squared_error: 4.4405 - val_loss: 17.5343 - val_root_mean_squared_error: 4.1874
#
# Epoch 4/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 15.5547 - root_mean_squared_error: 3.9439
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 15.8083 - root_mean_squared_error: 3.9760 - val_loss: 14.0368 - val_root_mean_squared_error: 3.7466
#
# Epoch 5/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 14.4483 - root_mean_squared_error: 3.8011
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12.6359 - root_mean_squared_error: 3.5547 - val_loss: 11.2090 - val_root_mean_squared_error: 3.3480
#
# Epoch 6/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 11.7178 - root_mean_squared_error: 3.4231
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.0967 - root_mean_squared_error: 3.1775 - val_loss: 8.9530 - val_root_mean_squared_error: 2.9922
#
# Epoch 7/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.5419 - root_mean_squared_error: 3.0890
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0947 - root_mean_squared_error: 2.8451 - val_loss: 7.1851 - val_root_mean_squared_error: 2.6805
#
# Epoch 8/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.4831 - root_mean_squared_error: 2.7355
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.5455 - root_mean_squared_error: 2.5584 - val_loss: 5.8207 - val_root_mean_squared_error: 2.4126
#
# Epoch 9/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9686 - root_mean_squared_error: 2.2290
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3628 - root_mean_squared_error: 2.3158 - val_loss: 4.7800 - val_root_mean_squared_error: 2.1863
#
# Epoch 10/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.3320 - root_mean_squared_error: 2.3091
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4676 - root_mean_squared_error: 2.1137 - val_loss: 3.9911 - val_root_mean_squared_error: 1.9978
#
# Epoch 11/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2215 - root_mean_squared_error: 2.0546
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7948 - root_mean_squared_error: 1.9480 - val_loss: 3.3983 - val_root_mean_squared_error: 1.8434
#
# Epoch 12/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2618 - root_mean_squared_error: 1.8060
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2900 - root_mean_squared_error: 1.8138 - val_loss: 2.9496 - val_root_mean_squared_error: 1.7174
#
# Epoch 13/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2675 - root_mean_squared_error: 1.8076
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9078 - root_mean_squared_error: 1.7052 - val_loss: 2.6083 - val_root_mean_squared_error: 1.6150
#
# Epoch 14/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7008 - root_mean_squared_error: 1.6434
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6146 - root_mean_squared_error: 1.6170 - val_loss: 2.3462 - val_root_mean_squared_error: 1.5317
#
# Epoch 15/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0526 - root_mean_squared_error: 1.7472
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3870 - root_mean_squared_error: 1.5450 - val_loss: 2.1423 - val_root_mean_squared_error: 1.4637
#
# Epoch 16/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4281 - root_mean_squared_error: 1.5582
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2083 - root_mean_squared_error: 1.4860 - val_loss: 1.9817 - val_root_mean_squared_error: 1.4077
#
# Epoch 17/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7651 - root_mean_squared_error: 1.3286
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0637 - root_mean_squared_error: 1.4366 - val_loss: 1.8526 - val_root_mean_squared_error: 1.3611
#
# Epoch 18/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1545 - root_mean_squared_error: 1.4678
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9439 - root_mean_squared_error: 1.3942 - val_loss: 1.7453 - val_root_mean_squared_error: 1.3211
#
# Epoch 19/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4572 - root_mean_squared_error: 1.5676
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8426 - root_mean_squared_error: 1.3574 - val_loss: 1.6562 - val_root_mean_squared_error: 1.2869
#
# Epoch 20/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4590 - root_mean_squared_error: 1.2079
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7560 - root_mean_squared_error: 1.3252 - val_loss: 1.5813 - val_root_mean_squared_error: 1.2575
#
# Epoch 21/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2278 - root_mean_squared_error: 1.4926
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6811 - root_mean_squared_error: 1.2966 - val_loss: 1.5169 - val_root_mean_squared_error: 1.2316
#
# Epoch 22/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1763 - root_mean_squared_error: 1.0846
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6146 - root_mean_squared_error: 1.2707 - val_loss: 1.4600 - val_root_mean_squared_error: 1.2083
#
# Epoch 23/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0729 - root_mean_squared_error: 1.0358
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5548 - root_mean_squared_error: 1.2469 - val_loss: 1.4101 - val_root_mean_squared_error: 1.1875
#
# Epoch 24/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7311 - root_mean_squared_error: 1.3157
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5012 - root_mean_squared_error: 1.2252 - val_loss: 1.3655 - val_root_mean_squared_error: 1.1686
#
# Epoch 25/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3762 - root_mean_squared_error: 1.1731
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4524 - root_mean_squared_error: 1.2052 - val_loss: 1.3259 - val_root_mean_squared_error: 1.1515
#
# Epoch 26/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5023 - root_mean_squared_error: 1.2257
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4078 - root_mean_squared_error: 1.1865 - val_loss: 1.2897 - val_root_mean_squared_error: 1.1357
#
# Epoch 27/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2392 - root_mean_squared_error: 1.1132
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3665 - root_mean_squared_error: 1.1690 - val_loss: 1.2564 - val_root_mean_squared_error: 1.1209
#
# Epoch 28/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3012 - root_mean_squared_error: 1.1407
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3283 - root_mean_squared_error: 1.1525 - val_loss: 1.2259 - val_root_mean_squared_error: 1.1072
#
# Epoch 29/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9597 - root_mean_squared_error: 0.9797
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2924 - root_mean_squared_error: 1.1368 - val_loss: 1.1976 - val_root_mean_squared_error: 1.0944
#
# Epoch 30/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2831 - root_mean_squared_error: 1.1327
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2592 - root_mean_squared_error: 1.1221 - val_loss: 1.1716 - val_root_mean_squared_error: 1.0824
#
# Epoch 31/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1392 - root_mean_squared_error: 1.0673
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2283 - root_mean_squared_error: 1.1083 - val_loss: 1.1473 - val_root_mean_squared_error: 1.0711
#
# Epoch 32/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2002 - root_mean_squared_error: 1.0955
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1994 - root_mean_squared_error: 1.0952 - val_loss: 1.1244 - val_root_mean_squared_error: 1.0604
#
# Epoch 33/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.1382 - root_mean_squared_error: 2.2668
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1721 - root_mean_squared_error: 1.0827 - val_loss: 1.1031 - val_root_mean_squared_error: 1.0503
#
# Epoch 34/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0027 - root_mean_squared_error: 1.0013
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1466 - root_mean_squared_error: 1.0708 - val_loss: 1.0833 - val_root_mean_squared_error: 1.0408
#
# Epoch 35/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8663 - root_mean_squared_error: 0.9307
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1227 - root_mean_squared_error: 1.0596 - val_loss: 1.0646 - val_root_mean_squared_error: 1.0318
#
# Epoch 36/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7707 - root_mean_squared_error: 0.8779
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1001 - root_mean_squared_error: 1.0489 - val_loss: 1.0469 - val_root_mean_squared_error: 1.0232
#
# Epoch 37/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8175 - root_mean_squared_error: 0.9041
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0789 - root_mean_squared_error: 1.0387 - val_loss: 1.0301 - val_root_mean_squared_error: 1.0150
#
# Epoch 38/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7990 - root_mean_squared_error: 0.8939
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0586 - root_mean_squared_error: 1.0289 - val_loss: 1.0146 - val_root_mean_squared_error: 1.0073
#
# Epoch 39/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9424 - root_mean_squared_error: 0.9708
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0394 - root_mean_squared_error: 1.0195 - val_loss: 0.9995 - val_root_mean_squared_error: 0.9998
#
# Epoch 40/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1948 - root_mean_squared_error: 1.0931
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0211 - root_mean_squared_error: 1.0105 - val_loss: 0.9853 - val_root_mean_squared_error: 0.9926
#
# Epoch 41/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0844 - root_mean_squared_error: 1.0413
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0038 - root_mean_squared_error: 1.0019 - val_loss: 0.9716 - val_root_mean_squared_error: 0.9857
#
# Epoch 42/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0609 - root_mean_squared_error: 1.0300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9872 - root_mean_squared_error: 0.9936 - val_loss: 0.9586 - val_root_mean_squared_error: 0.9791
#
# Epoch 43/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7601 - root_mean_squared_error: 0.8718
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9714 - root_mean_squared_error: 0.9856 - val_loss: 0.9462 - val_root_mean_squared_error: 0.9727
#
# Epoch 44/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9649 - root_mean_squared_error: 0.9823
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9563 - root_mean_squared_error: 0.9779 - val_loss: 0.9342 - val_root_mean_squared_error: 0.9665
#
# Epoch 45/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8753 - root_mean_squared_error: 0.9356
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9419 - root_mean_squared_error: 0.9705 - val_loss: 0.9227 - val_root_mean_squared_error: 0.9606
#
# Epoch 46/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7645 - root_mean_squared_error: 0.8744
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9281 - root_mean_squared_error: 0.9634 - val_loss: 0.9117 - val_root_mean_squared_error: 0.9548
#
# Epoch 47/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9811 - root_mean_squared_error: 0.9905
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9149 - root_mean_squared_error: 0.9565 - val_loss: 0.9010 - val_root_mean_squared_error: 0.9492
#
# Epoch 48/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6995 - root_mean_squared_error: 0.8364
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9021 - root_mean_squared_error: 0.9498 - val_loss: 0.8905 - val_root_mean_squared_error: 0.9437
#
# Epoch 49/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9242 - root_mean_squared_error: 0.9613
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8898 - root_mean_squared_error: 0.9433 - val_loss: 0.8809 - val_root_mean_squared_error: 0.9385
#
# Epoch 50/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9628 - root_mean_squared_error: 0.9812
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8766 - root_mean_squared_error: 0.9363 - val_loss: 0.8711 - val_root_mean_squared_error: 0.9333
#
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7419 - root_mean_squared_error: 0.8613
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 0.8711 - root_mean_squared_error: 0.9333
#
#  20%|██        | 1/5 [00:13<00:36,  9.19s/trial, best loss: 0.04922802001237869]
# 2026/01/24 05:43:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run capricious-snake-905 at: http://127.0.0.1:5000/#/experiments/306340854970463397/runs/5139e97b518943639797dc5ea1555f2c.
#
# 2026/01/24 05:43:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/306340854970463397.
# Epoch 1/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - loss: 28.1598 - root_mean_squared_error: 5.3066
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.6252 - root_mean_squared_error: 3.9529 - val_loss: 5.9223 - val_root_mean_squared_error: 2.4336
#
# Epoch 2/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.3199 - root_mean_squared_error: 2.5139
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3861 - root_mean_squared_error: 1.8401 - val_loss: 2.1430 - val_root_mean_squared_error: 1.4639
#
# Epoch 3/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6922 - root_mean_squared_error: 1.3009
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8822 - root_mean_squared_error: 1.3719 - val_loss: 1.6666 - val_root_mean_squared_error: 1.2910
#
# Epoch 4/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1303 - root_mean_squared_error: 1.4596
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5601 - root_mean_squared_error: 1.2490 - val_loss: 1.4427 - val_root_mean_squared_error: 1.2011
#
# Epoch 5/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9042 - root_mean_squared_error: 1.3799
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3589 - root_mean_squared_error: 1.1657 - val_loss: 1.2886 - val_root_mean_squared_error: 1.1352
#
# Epoch 6/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8183 - root_mean_squared_error: 0.9046
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2080 - root_mean_squared_error: 1.0991 - val_loss: 1.1696 - val_root_mean_squared_error: 1.0815
#
# Epoch 7/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0777 - root_mean_squared_error: 1.0381
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0947 - root_mean_squared_error: 1.0463 - val_loss: 1.0788 - val_root_mean_squared_error: 1.0386
#
# Epoch 8/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1517 - root_mean_squared_error: 1.0732
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0031 - root_mean_squared_error: 1.0015 - val_loss: 1.0002 - val_root_mean_squared_error: 1.0001
#
# Epoch 9/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9621 - root_mean_squared_error: 0.9809
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9279 - root_mean_squared_error: 0.9633 - val_loss: 0.9366 - val_root_mean_squared_error: 0.9678
#
# Epoch 10/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7884 - root_mean_squared_error: 0.8879
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8643 - root_mean_squared_error: 0.9297 - val_loss: 0.8804 - val_root_mean_squared_error: 0.9383
#
# Epoch 11/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5360 - root_mean_squared_error: 0.7321
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8088 - root_mean_squared_error: 0.8993 - val_loss: 0.8308 - val_root_mean_squared_error: 0.9115
#
# Epoch 12/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5458 - root_mean_squared_error: 0.7388
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7608 - root_mean_squared_error: 0.8722 - val_loss: 0.7878 - val_root_mean_squared_error: 0.8876
#
# Epoch 13/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4803 - root_mean_squared_error: 0.6931
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7164 - root_mean_squared_error: 0.8464 - val_loss: 0.7476 - val_root_mean_squared_error: 0.8646
#
# Epoch 14/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8961 - root_mean_squared_error: 0.9466
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6762 - root_mean_squared_error: 0.8223 - val_loss: 0.7111 - val_root_mean_squared_error: 0.8433
#
# Epoch 15/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5115 - root_mean_squared_error: 0.7152
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6404 - root_mean_squared_error: 0.8002 - val_loss: 0.6760 - val_root_mean_squared_error: 0.8222
#
# Epoch 16/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3417 - root_mean_squared_error: 0.5846
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6064 - root_mean_squared_error: 0.7787 - val_loss: 0.6436 - val_root_mean_squared_error: 0.8023
#
# Epoch 17/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7782 - root_mean_squared_error: 0.8822
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5750 - root_mean_squared_error: 0.7583 - val_loss: 0.6142 - val_root_mean_squared_error: 0.7837
#
# Epoch 18/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5103 - root_mean_squared_error: 0.7144
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5460 - root_mean_squared_error: 0.7389 - val_loss: 0.5838 - val_root_mean_squared_error: 0.7641
#
# Epoch 19/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4051 - root_mean_squared_error: 0.6365
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5194 - root_mean_squared_error: 0.7207 - val_loss: 0.5589 - val_root_mean_squared_error: 0.7476
#
# Epoch 20/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5444 - root_mean_squared_error: 0.7378
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4941 - root_mean_squared_error: 0.7030 - val_loss: 0.5333 - val_root_mean_squared_error: 0.7303
#
# Epoch 21/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3521 - root_mean_squared_error: 0.5934
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4707 - root_mean_squared_error: 0.6861 - val_loss: 0.5100 - val_root_mean_squared_error: 0.7141
#
# Epoch 22/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4072 - root_mean_squared_error: 0.6381
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4479 - root_mean_squared_error: 0.6693 - val_loss: 0.4874 - val_root_mean_squared_error: 0.6982
#
# Epoch 23/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4184 - root_mean_squared_error: 0.6469
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4268 - root_mean_squared_error: 0.6533 - val_loss: 0.4662 - val_root_mean_squared_error: 0.6828
#
# Epoch 24/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3321 - root_mean_squared_error: 0.5763
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4069 - root_mean_squared_error: 0.6379 - val_loss: 0.4464 - val_root_mean_squared_error: 0.6681
#
# Epoch 25/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3504 - root_mean_squared_error: 0.5919
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3879 - root_mean_squared_error: 0.6228 - val_loss: 0.4274 - val_root_mean_squared_error: 0.6537
#
# Epoch 26/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2711 - root_mean_squared_error: 0.5207
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3700 - root_mean_squared_error: 0.6083 - val_loss: 0.4100 - val_root_mean_squared_error: 0.6403
#
# Epoch 27/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3447 - root_mean_squared_error: 0.5871
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3528 - root_mean_squared_error: 0.5940 - val_loss: 0.3924 - val_root_mean_squared_error: 0.6264
#
# Epoch 28/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3479 - root_mean_squared_error: 0.5898
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3365 - root_mean_squared_error: 0.5801 - val_loss: 0.3751 - val_root_mean_squared_error: 0.6125
#
# Epoch 29/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2444 - root_mean_squared_error: 0.4944
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3212 - root_mean_squared_error: 0.5667 - val_loss: 0.3596 - val_root_mean_squared_error: 0.5996
#
# Epoch 30/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2440 - root_mean_squared_error: 0.4939
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3065 - root_mean_squared_error: 0.5536 - val_loss: 0.3446 - val_root_mean_squared_error: 0.5870
#
# Epoch 31/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3419 - root_mean_squared_error: 0.5848
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2926 - root_mean_squared_error: 0.5409 - val_loss: 0.3302 - val_root_mean_squared_error: 0.5746
#
# Epoch 32/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3842 - root_mean_squared_error: 0.6198
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2794 - root_mean_squared_error: 0.5286 - val_loss: 0.3158 - val_root_mean_squared_error: 0.5620
#
# Epoch 33/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2294 - root_mean_squared_error: 0.4790
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2668 - root_mean_squared_error: 0.5165 - val_loss: 0.3032 - val_root_mean_squared_error: 0.5506
#
# Epoch 34/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2474 - root_mean_squared_error: 0.4974
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2548 - root_mean_squared_error: 0.5048 - val_loss: 0.2908 - val_root_mean_squared_error: 0.5392
#
# Epoch 35/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1887 - root_mean_squared_error: 0.4344
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2434 - root_mean_squared_error: 0.4933 - val_loss: 0.2785 - val_root_mean_squared_error: 0.5277
#
# Epoch 36/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1329 - root_mean_squared_error: 0.3645
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2324 - root_mean_squared_error: 0.4820 - val_loss: 0.2672 - val_root_mean_squared_error: 0.5169
#
# Epoch 37/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.2327 - root_mean_squared_error: 0.4824
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2218 - root_mean_squared_error: 0.4709 - val_loss: 0.2564 - val_root_mean_squared_error: 0.5063
#
# Epoch 38/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2097 - root_mean_squared_error: 0.4579
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2121 - root_mean_squared_error: 0.4606 - val_loss: 0.2460 - val_root_mean_squared_error: 0.4960
#
# Epoch 39/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1710 - root_mean_squared_error: 0.4135
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2026 - root_mean_squared_error: 0.4501 - val_loss: 0.2359 - val_root_mean_squared_error: 0.4856
#
# Epoch 40/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1422 - root_mean_squared_error: 0.3771
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1937 - root_mean_squared_error: 0.4401 - val_loss: 0.2264 - val_root_mean_squared_error: 0.4758
#
# Epoch 41/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1779 - root_mean_squared_error: 0.4218
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1851 - root_mean_squared_error: 0.4302 - val_loss: 0.2176 - val_root_mean_squared_error: 0.4665
#
# Epoch 42/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2128 - root_mean_squared_error: 0.4613
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1771 - root_mean_squared_error: 0.4208 - val_loss: 0.2090 - val_root_mean_squared_error: 0.4572
#
# Epoch 43/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1618 - root_mean_squared_error: 0.4022
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1693 - root_mean_squared_error: 0.4115 - val_loss: 0.2006 - val_root_mean_squared_error: 0.4478
#
# Epoch 44/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1213 - root_mean_squared_error: 0.3482
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1620 - root_mean_squared_error: 0.4024 - val_loss: 0.1928 - val_root_mean_squared_error: 0.4391
#
# Epoch 45/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1596 - root_mean_squared_error: 0.3995
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1550 - root_mean_squared_error: 0.3937 - val_loss: 0.1851 - val_root_mean_squared_error: 0.4302
#
# Epoch 46/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1172 - root_mean_squared_error: 0.3424
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1482 - root_mean_squared_error: 0.3850 - val_loss: 0.1780 - val_root_mean_squared_error: 0.4219
#
# Epoch 47/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1550 - root_mean_squared_error: 0.3937
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1418 - root_mean_squared_error: 0.3766 - val_loss: 0.1712 - val_root_mean_squared_error: 0.4137
#
# Epoch 48/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1268 - root_mean_squared_error: 0.3560
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1359 - root_mean_squared_error: 0.3686 - val_loss: 0.1646 - val_root_mean_squared_error: 0.4057
#
# Epoch 49/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2147 - root_mean_squared_error: 0.4633
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1299 - root_mean_squared_error: 0.3604 - val_loss: 0.1585 - val_root_mean_squared_error: 0.3981
#
# Epoch 50/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1010 - root_mean_squared_error: 0.3179
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1243 - root_mean_squared_error: 0.3525 - val_loss: 0.1521 - val_root_mean_squared_error: 0.3900
#
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0887 - root_mean_squared_error: 0.2979
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.1521 - root_mean_squared_error: 0.3900
#
#  40%|████      | 2/5 [00:21<00:24,  8.23s/trial, best loss: 0.04922802001237869]
# ...
#
# Epoch 4/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 24.1771 - root_mean_squared_error: 4.9170
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 21.9570 - root_mean_squared_error: 4.6858 - val_loss: 20.4777 - val_root_mean_squared_error: 4.5252
#
# Epoch 5/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 19.7009 - root_mean_squared_error: 4.4386
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19.4456 - root_mean_squared_error: 4.4097 - val_loss: 18.1588 - val_root_mean_squared_error: 4.2613
#
# Epoch 6/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.8987 - root_mean_squared_error: 4.2307
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 17.1972 - root_mean_squared_error: 4.1469 - val_loss: 16.0747 - val_root_mean_squared_error: 4.0093
#
# Epoch 7/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 15.1634 - root_mean_squared_error: 3.8940
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 15.1881 - root_mean_squared_error: 3.8972 - val_loss: 14.2054 - val_root_mean_squared_error: 3.7690
#
# Epoch 8/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 14.9323 - root_mean_squared_error: 3.8642
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.3921 - root_mean_squared_error: 3.6595 - val_loss: 12.5468 - val_root_mean_squared_error: 3.5421
#
# Epoch 9/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 13.3373 - root_mean_squared_error: 3.6520
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.8018 - root_mean_squared_error: 3.4354 - val_loss: 11.0734 - val_root_mean_squared_error: 3.3277
#
# Epoch 10/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 10.7205 - root_mean_squared_error: 3.2742
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.3959 - root_mean_squared_error: 3.2243 - val_loss: 9.7776 - val_root_mean_squared_error: 3.1269
#
# Epoch 11/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.0829 - root_mean_squared_error: 3.1754
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1644 - root_mean_squared_error: 3.0273 - val_loss: 8.6420 - val_root_mean_squared_error: 2.9397
#
# Epoch 12/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.1535 - root_mean_squared_error: 2.8554
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0904 - root_mean_squared_error: 2.8444 - val_loss: 7.6514 - val_root_mean_squared_error: 2.7661
#
# Epoch 13/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.8536 - root_mean_squared_error: 2.6179
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.1587 - root_mean_squared_error: 2.6756 - val_loss: 6.7970 - val_root_mean_squared_error: 2.6071
#
# Epoch 14/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.5911 - root_mean_squared_error: 2.5673
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3586 - root_mean_squared_error: 2.5216 - val_loss: 6.0584 - val_root_mean_squared_error: 2.4614
#
# Epoch 15/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.6774 - root_mean_squared_error: 2.3827
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6711 - root_mean_squared_error: 2.3814 - val_loss: 5.4266 - val_root_mean_squared_error: 2.3295
#
# Epoch 16/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.7128 - root_mean_squared_error: 2.3901
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0849 - root_mean_squared_error: 2.2550 - val_loss: 4.8891 - val_root_mean_squared_error: 2.2111
#
# Epoch 17/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1206 - root_mean_squared_error: 2.0299
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5883 - root_mean_squared_error: 2.1420 - val_loss: 4.4320 - val_root_mean_squared_error: 2.1052
#
# Epoch 18/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2640 - root_mean_squared_error: 2.0649
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1668 - root_mean_squared_error: 2.0413 - val_loss: 4.0454 - val_root_mean_squared_error: 2.0113
#
# Epoch 19/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3469 - root_mean_squared_error: 1.8294
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8118 - root_mean_squared_error: 1.9524 - val_loss: 3.7156 - val_root_mean_squared_error: 1.9276
#
# Epoch 20/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2548 - root_mean_squared_error: 1.8041
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5113 - root_mean_squared_error: 1.8738 - val_loss: 3.4415 - val_root_mean_squared_error: 1.8551
#
# Epoch 21/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4292 - root_mean_squared_error: 1.8518
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2591 - root_mean_squared_error: 1.8053 - val_loss: 3.2065 - val_root_mean_squared_error: 1.7907
#
# Epoch 22/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1591 - root_mean_squared_error: 1.7774
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0447 - root_mean_squared_error: 1.7449 - val_loss: 3.0086 - val_root_mean_squared_error: 1.7345
#
# Epoch 23/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0622 - root_mean_squared_error: 1.7499
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8622 - root_mean_squared_error: 1.6918 - val_loss: 2.8409 - val_root_mean_squared_error: 1.6855
#
# Epoch 24/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7484 - root_mean_squared_error: 1.6578
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7070 - root_mean_squared_error: 1.6453 - val_loss: 2.6954 - val_root_mean_squared_error: 1.6418
#
# Epoch 25/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.8877 - root_mean_squared_error: 1.6993
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5732 - root_mean_squared_error: 1.6041 - val_loss: 2.5706 - val_root_mean_squared_error: 1.6033
#
# Epoch 26/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6736 - root_mean_squared_error: 1.6351
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4578 - root_mean_squared_error: 1.5677 - val_loss: 2.4639 - val_root_mean_squared_error: 1.5697
#
# Epoch 27/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8841 - root_mean_squared_error: 1.3726
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3569 - root_mean_squared_error: 1.5352 - val_loss: 2.3707 - val_root_mean_squared_error: 1.5397
#
# Epoch 28/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7198 - root_mean_squared_error: 1.3114
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2684 - root_mean_squared_error: 1.5061 - val_loss: 2.2883 - val_root_mean_squared_error: 1.5127
#
# Epoch 29/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7728 - root_mean_squared_error: 1.3315
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1905 - root_mean_squared_error: 1.4800 - val_loss: 2.2162 - val_root_mean_squared_error: 1.4887
#
# Epoch 30/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3290 - root_mean_squared_error: 1.5261
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1207 - root_mean_squared_error: 1.4563 - val_loss: 2.1503 - val_root_mean_squared_error: 1.4664
#
# Epoch 31/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6986 - root_mean_squared_error: 1.3033
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0577 - root_mean_squared_error: 1.4345 - val_loss: 2.0921 - val_root_mean_squared_error: 1.4464
#
# Epoch 32/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0387 - root_mean_squared_error: 1.4278
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0005 - root_mean_squared_error: 1.4144 - val_loss: 2.0395 - val_root_mean_squared_error: 1.4281
#
# Epoch 33/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0091 - root_mean_squared_error: 1.4174
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9487 - root_mean_squared_error: 1.3960 - val_loss: 1.9920 - val_root_mean_squared_error: 1.4114
#
# Epoch 34/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6965 - root_mean_squared_error: 1.6421
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9009 - root_mean_squared_error: 1.3787 - val_loss: 1.9480 - val_root_mean_squared_error: 1.3957
#
# Epoch 35/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6496 - root_mean_squared_error: 1.2844
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8564 - root_mean_squared_error: 1.3625 - val_loss: 1.9084 - val_root_mean_squared_error: 1.3814
#
# Epoch 36/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5497 - root_mean_squared_error: 1.2449
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8152 - root_mean_squared_error: 1.3473 - val_loss: 1.8700 - val_root_mean_squared_error: 1.3675
#
# Epoch 37/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3609 - root_mean_squared_error: 1.1666
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7769 - root_mean_squared_error: 1.3330 - val_loss: 1.8349 - val_root_mean_squared_error: 1.3546
#
# Epoch 38/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7416 - root_mean_squared_error: 1.3197
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7405 - root_mean_squared_error: 1.3193 - val_loss: 1.8021 - val_root_mean_squared_error: 1.3424
#
# Epoch 39/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1028 - root_mean_squared_error: 1.0501
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7060 - root_mean_squared_error: 1.3061 - val_loss: 1.7712 - val_root_mean_squared_error: 1.3309
#
# Epoch 40/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4374 - root_mean_squared_error: 1.1989
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6737 - root_mean_squared_error: 1.2937 - val_loss: 1.7423 - val_root_mean_squared_error: 1.3200
#
# Epoch 41/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6324 - root_mean_squared_error: 1.2776
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6430 - root_mean_squared_error: 1.2818 - val_loss: 1.7141 - val_root_mean_squared_error: 1.3092
#
# Epoch 42/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5092 - root_mean_squared_error: 1.2285
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6136 - root_mean_squared_error: 1.2703 - val_loss: 1.6881 - val_root_mean_squared_error: 1.2993
#
# Epoch 43/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5194 - root_mean_squared_error: 1.2327
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5859 - root_mean_squared_error: 1.2593 - val_loss: 1.6627 - val_root_mean_squared_error: 1.2895
#
# Epoch 44/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1113 - root_mean_squared_error: 1.4530
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5592 - root_mean_squared_error: 1.2487 - val_loss: 1.6389 - val_root_mean_squared_error: 1.2802
#
# Epoch 45/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5186 - root_mean_squared_error: 1.2323
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5336 - root_mean_squared_error: 1.2384 - val_loss: 1.6164 - val_root_mean_squared_error: 1.2714
#
# Epoch 46/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4435 - root_mean_squared_error: 1.5632
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5093 - root_mean_squared_error: 1.2285 - val_loss: 1.5941 - val_root_mean_squared_error: 1.2626
#
# Epoch 47/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6962 - root_mean_squared_error: 1.3024
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4859 - root_mean_squared_error: 1.2190 - val_loss: 1.5735 - val_root_mean_squared_error: 1.2544
#
# Epoch 48/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1346 - root_mean_squared_error: 1.0652
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4633 - root_mean_squared_error: 1.2097 - val_loss: 1.5536 - val_root_mean_squared_error: 1.2464
#
# Epoch 49/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1195 - root_mean_squared_error: 1.0581
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4417 - root_mean_squared_error: 1.2007 - val_loss: 1.5344 - val_root_mean_squared_error: 1.2387
#
# Epoch 50/50
#
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8340 - root_mean_squared_error: 1.3543
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4210 - root_mean_squared_error: 1.1920 - val_loss: 1.5156 - val_root_mean_squared_error: 1.2311
#
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2288 - root_mean_squared_error: 1.1085
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 1.5156 - root_mean_squared_error: 1.2311
#
#  80%|████████  | 4/5 [00:36<00:07,  7.74s/trial, best loss: 0.04922802001237869]
# 2026/01/24 05:44:10 INFO mlflow.tracking._tracking_service.client: 🏃 View run unruly-shrew-743 at: http://127.0.0.1:5000/#/experiments/306340854970463397/runs/7bb04e05d0ac4a40a38a5fdc02ff78fa.
#
# 2026/01/24 05:44:10 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/306340854970463397.
# 100%|██████████| 5/5 [00:39<00:00,  7.84s/trial, best loss: 0.04922802001237869]
# 2026/01/24 05:44:13 INFO mlflow.tracking._tracking_service.client: 🏃 View run upset-loon-796 at: http://127.0.0.1:5000/#/experiments/306340854970463397/runs/13baceb1309e43369a5cf3f950e53c87.
# 2026/01/24 05:44:13 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/306340854970463397.

# %%
## validating model
import mlflow.pyfunc

model_uri = 'runs:/6d4ec9c4d2244eeb8dba78b599b86e45/model'
loaded_model = mlflow.pyfunc.load_model(model_uri)
# Out:
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[18], line 5
#       2 import mlflow.pyfunc
#       4 model_uri = 'runs:/6d4ec9c4d2244eeb8dba78b599b86e45/model'
# ----> 5 loaded_model = mlflow.pyfunc.load_model(model_uri)
#
# File ~/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/mlflow/tracing/provider.py:268, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     266 disable()
#     267 try:
# --> 268     is_func_called, result = True, f(*args, **kwargs)
#     269 finally:
#     270     enable()
#
# File ~/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/mlflow/pyfunc/__init__.py:1017, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1013         entity_list.append(Entity(job=job_entity))
#    1015     lineage_header_info = LineageHeaderInfo(entities=entity_list) if entity_list else None
# -> 1017 local_path = _download_artifact_from_uri(
#    1018     artifact_uri=model_uri, output_path=dst_path, lineage_header_info=lineage_header_info
#    1019 )
#    1021 if not suppress_warnings:
#    1022     model_requirements = _get_pip_requirements_from_model_path(local_path)
#
# File ~/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/mlflow/tracking/artifact_utils.py:108, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info)
#     100 """
#     101 Args:
#     102     artifact_uri: The *absolute* URI of the artifact to download.
#    (...)    105     lineage_header_info: The model lineage header info to be consumed by lineage services.
#     106 """
#     107 root_uri, artifact_path = _get_root_uri_and_artifact_path(artifact_uri)
# --> 108 repo = get_artifact_repository(artifact_uri=root_uri)
#     110 if isinstance(repo, ModelsArtifactRepository):
#     111     return repo.download_artifacts(
#     112         artifact_path=artifact_path,
#     113         dst_path=output_path,
#     114         lineage_header_info=lineage_header_info,
#     115     )
#
# File ~/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/mlflow/store/artifact/artifact_repository_registry.py:132, in get_artifact_repository(artifact_uri)
#     119 def get_artifact_repository(artifact_uri: str) -> ArtifactRepository:
#     120     """
#     121     Get an artifact repository from the registry based on the scheme of artifact_uri
#     122
#    (...)    130         requirements.
#     131     """
# --> 132     return _artifact_repository_registry.get_artifact_repository(artifact_uri)
#
# File ~/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/mlflow/store/artifact/artifact_repository_registry.py:77, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri)
#      72 if repository is None:
#      73     raise MlflowException(
#      74         f"Could not find a registered artifact repository for: {artifact_uri}. "
#      75         f"Currently registered schemes are: {list(self._registry.keys())}"
#      76     )
# ---> 77 return repository(artifact_uri)
#
# File ~/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/mlflow/store/artifact/runs_artifact_repo.py:26, in RunsArtifactRepository.__init__(self, artifact_uri)
#      23 from mlflow.store.artifact.artifact_repository_registry import get_artifact_repository
#      25 super().__init__(artifact_uri)
# ---> 26 uri = RunsArtifactRepository.get_underlying_uri(artifact_uri)
#      27 self.repo = get_artifact_repository(uri)
#
# File ~/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/mlflow/store/artifact/runs_artifact_repo.py:39, in RunsArtifactRepository.get_underlying_uri(runs_uri)
#      37 (run_id, artifact_path) = RunsArtifactRepository.parse_runs_uri(runs_uri)
#      38 tracking_uri = get_databricks_profile_uri_from_artifact_uri(runs_uri)
# ---> 39 uri = get_artifact_uri(run_id, artifact_path, tracking_uri)
#      40 assert not RunsArtifactRepository.is_runs_uri(uri)  # avoid an infinite loop
#      41 return add_databricks_profile_info_to_artifact_uri(uri, tracking_uri)
#
# File ~/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/mlflow/tracking/artifact_utils.py:52, in get_artifact_uri(run_id, artifact_path, tracking_uri)
#      46     raise MlflowException(
#      47         message="A run_id must be specified in order to obtain an artifact uri!",
#      48         error_code=INVALID_PARAMETER_VALUE,
#      49     )
#      51 store = _get_store(tracking_uri)
# ---> 52 run = store.get_run(run_id)
#      53 # Maybe move this method to RunsArtifactRepository so the circular dependency is clearer.
#      54 assert urllib.parse.urlparse(run.info.artifact_uri).scheme != "runs"  # avoid an infinite loop
#
# File ~/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/mlflow/store/tracking/rest_store.py:166, in RestStore.get_run(self, run_id)
#     156 """
#     157 Fetch the run from backend store
#     158
#    (...)    163     A single Run object if it exists, otherwise raises an Exception
#     164 """
#     165 req_body = message_to_json(GetRun(run_uuid=run_id, run_id=run_id))
# --> 166 response_proto = self._call_endpoint(GetRun, req_body)
#     167 return Run.from_proto(response_proto.run)
#
# File ~/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/mlflow/store/tracking/rest_store.py:82, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      80     endpoint, method = _METHOD_TO_INFO[api]
#      81 response_proto = api.Response()
# ---> 82 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File ~/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/mlflow/utils/rest_utils.py:370, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     367     call_kwargs["json"] = json_body
#     368     response = http_request(**call_kwargs)
# --> 370 response = verify_rest_response(response, endpoint)
#     371 response_to_parse = response.text
#     372 js_dict = json.loads(response_to_parse)
#
# File ~/anaconda3/envs/conda-env-3-11/lib/python3.11/site-packages/mlflow/utils/rest_utils.py:240, in verify_rest_response(response, endpoint)
#     238 if response.status_code != 200:
#     239     if _can_parse_as_json_object(response.text):
# --> 240         raise RestException(json.loads(response.text))
#     241     else:
#     242         base_msg = (
#     243             f"API request to endpoint {endpoint} "
#     244             f"failed with error code {response.status_code} != 200"
#     245         )
#
# RestException: RESOURCE_DOES_NOT_EXIST: Run '6d4ec9c4d2244eeb8dba78b599b86e45' not found

# %%
from mlflow.models import convert_input_example_to_serving_input

# %%
serving_payload = convert_input_example_to_serving_input(X_test)

# %%
from mlflow.models import validate_serving_input

# %%
validate_serving_input(model_uri,serving_payload)
# Out:
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[5.003921 ],
#        [5.9681168],
#        [6.0304794],
#        ...,
#        [4.9877253],
#        [5.997781 ],
#        [6.0241003]], dtype=float32)
