# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.pipeline import Pipeline
from scikeras.wrappers import KerasClassifier
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Input
from tensorflow.keras.callbacks import EarlyStopping

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Arannamoy/datasets/refs/heads/main/Churn_Modelling/Churn_Modelling.csv")

# %%
df=df.drop(['RowNumber','CustomerId','Surname'],axis=1)

# %%
label_encoder=LabelEncoder()
df['Gender']=label_encoder.fit_transform(df['Gender'])

df['Geography']=label_encoder.fit_transform(df['Geography'])

# %%
df.head(15)
# Out:
#     CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0           619          0       0   42       2       0.00              1
# 1           608          2       0   41       1   83807.86              1
# 2           502          0       0   42       8  159660.80              3
# 3           699          0       0   39       1       0.00              2
# 4           850          2       0   43       2  125510.82              1
# 5           645          2       1   44       8  113755.78              2
# 6           822          0       1   50       7       0.00              2
# 7           376          1       0   29       4  115046.74              4
# 8           501          0       1   44       4  142051.07              2
# 9           684          0       1   27       2  134603.88              1
# 10          528          0       1   31       6  102016.72              2
# 11          497          2       1   24       3       0.00              2
# 12          476          0       0   34      10       0.00              2
# 13          549          0       0   25       5       0.00              2
# 14          635          2       0   35       7       0.00              2
#
#     HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0           1               1        101348.88       1
# 1           0               1        112542.58       0
# 2           1               0        113931.57       1
# 3           0               0         93826.63       0
# 4           1               1         79084.10       0
# 5           1               0        149756.71       1
# 6           1               1         10062.80       0
# 7           1               0        119346.88       1
# 8           0               1         74940.50       0
# 9           1               1         71725.73       0
# 10          0               0         80181.12       0
# 11          1               0         76390.01       0
# 12          1               0         26260.98       0
# 13          0               0        190857.79       0
# 14          1               1         65951.65       0

# %%
X=df.drop('Exited',axis=1)
y=df['Exited']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.25)

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
import pickle

# %%
with open("label_encoder.pkl","wb") as fl:
    pickle.dump(label_encoder,fl)

with open("scaler.pkl","wb") as fl:
    pickle.dump(scaler,fl)

# %%
### Define a function to create a model and try different parameter

def create_model(neurons=32,layers=1):
    tf.keras.backend.clear_session()
    model=Sequential()
    # model.add(Input(shape=(X_train.shape[1],)))
    # model.add(Dense(neurons,activation=tf.keras.activations.relu))
    model.add(Dense(neurons,activation='relu',input_shape=(X_train.shape[1],)))
    for _ in range(layers-1):
        model.add(Dense(neurons,activation=tf.keras.activations.relu))

    model.add(Dense(1,activation=tf.keras.activations.sigmoid))
    model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.01),loss=tf.losses.BinaryCrossentropy(),metrics=['accuracy'])

    return model

# %%
# Create a keras classifier
model=KerasClassifier(layers=1,neurons=32,build_fn=create_model,epochs=50,batch_size=10,verbose=0)

# %%
# define the grid search parameter

param_grid={
    "neurons":[16,32,64,128],
    "layers":[1,2,3],
    "batch_size":[10,20],
    "epochs":[50,100]
}

# %%
grid=GridSearchCV(estimator=model,param_grid=param_grid,n_jobs=1,cv=3)
grid_result=grid.fit(X_train,y_train)

print("Best %f using %s"% (grid_result.best_score_,grid_result.best_params_))
# Out:
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1771086795.719965   54572 cuda_executor.cc:508] failed to allocate 27.20MiB (28526336 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086795.720009   54572 cuda_executor.cc:508] failed to allocate 24.48MiB (25673728 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086795.720029   54572 cuda_executor.cc:508] failed to allocate 22.04MiB (23106560 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086795.720048   54572 cuda_executor.cc:508] failed to allocate 19.83MiB (20795904 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086795.720067   54572 cuda_executor.cc:508] failed to allocate 17.85MiB (18716416 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086795.720085   54572 cuda_executor.cc:508] failed to allocate 16.06MiB (16844800 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2026-02-14 22:33:15.720091: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-02-14 22:33:15.723301: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes. [tf-allocator-allocation-error='']
# 2026-02-14 22:33:15.723317: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1771086796.229667   54576 cuda_executor.cc:508] failed to allocate 27.20MiB (28526336 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086796.229710   54576 cuda_executor.cc:508] failed to allocate 24.48MiB (25673728 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086796.229731   54576 cuda_executor.cc:508] failed to allocate 22.04MiB (23106560 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086796.229751   54576 cuda_executor.cc:508] failed to allocate 19.83MiB (20795904 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086796.229772   54576 cuda_executor.cc:508] failed to allocate 17.85MiB (18716416 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086796.229792   54576 cuda_executor.cc:508] failed to allocate 16.06MiB (16844800 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2026-02-14 22:33:16.229798: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-02-14 22:33:16.233006: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes. [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1771086796.718856   54577 cuda_executor.cc:508] failed to allocate 27.20MiB (28526336 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086796.718895   54577 cuda_executor.cc:508] failed to allocate 24.48MiB (25673728 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086796.718915   54577 cuda_executor.cc:508] failed to allocate 22.04MiB (23106560 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086796.718936   54577 cuda_executor.cc:508] failed to allocate 19.83MiB (20795904 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086796.718956   54577 cuda_executor.cc:508] failed to allocate 17.85MiB (18716416 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# I0000 00:00:1771086796.718976   54577 cuda_executor.cc:508] failed to allocate 16.06MiB (16844800 bytes) from device: RESOURCE_EXHAUSTED: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2026-02-14 22:33:16.718982: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-02-14 22:33:16.722979: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes. [tf-allocator-allocation-error='']
# 2026-02-14 22:33:16.723003: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1771086797.380230   54575 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-14 22:35:42.428690: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-02-14 22:35:42.431918: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777856 bytes. [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-14 22:35:43.001836: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-02-14 22:35:43.005111: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777856 bytes. [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-14 22:35:43.580058: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-02-14 22:35:43.584256: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes. [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-14 22:38:25.543003: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-02-14 22:38:25.546796: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes. [tf-allocator-allocation-error='']
# 2026-02-14 22:38:25.546817: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-14 22:38:26.269413: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-02-14 22:38:26.274183: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes. [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-14 22:38:26.946014: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-02-14 22:38:26.949874: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes. [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-14 22:41:19.590365: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-02-14 22:41:19.593795: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777256 bytes. [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-14 22:41:20.152462: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777256 bytes. [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-14 22:41:20.705730: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777256 bytes. [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-14 22:46:04.046663: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes. [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-14 22:46:04.690977: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes. [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-14 22:46:05.317467: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes. [tf-allocator-allocation-error='']
# 2026-02-14 22:46:05.317491: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777280 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
#
I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 16640 totalling 16.2KiB
# 2026-02-14 23:00:08.577127: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 18432 totalling 18.0KiB
# 2026-02-14 23:00:08.577128: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 20224 totalling 19.8KiB
# 2026-02-14 23:00:08.577129: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 3 Chunks of size 24064 totalling 70.5KiB
# 2026-02-14 23:00:08.577131: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 24576 totalling 24.0KiB
# 2026-02-14 23:00:08.577132: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 25856 totalling 25.2KiB
# 2026-02-14 23:00:08.577133: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 28672 totalling 56.0KiB
# 2026-02-14 23:00:08.577134: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 28928 totalling 28.2KiB
# 2026-02-14 23:00:08.577135: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 30208 totalling 29.5KiB
# 2026-02-14 23:00:08.577136: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 47 Chunks of size 65536 totalling 2.94MiB
# 2026-02-14 23:00:08.577137: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 5 Chunks of size 69120 totalling 337.5KiB
# 2026-02-14 23:00:08.577138: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 82176 totalling 160.5KiB
# 2026-02-14 23:00:08.577139: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 91648 totalling 89.5KiB
# 2026-02-14 23:00:08.577140: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 99584 totalling 97.2KiB
# 2026-02-14 23:00:08.577141: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 3 Chunks of size 110848 totalling 324.8KiB
# 2026-02-14 23:00:08.577142: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 124416 totalling 121.5KiB
# 2026-02-14 23:00:08.577143: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 200192 totalling 195.5KiB
# 2026-02-14 23:00:08.577144: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 300032 totalling 293.0KiB
# 2026-02-14 23:00:08.577145: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 21937664 totalling 20.92MiB
# 2026-02-14 23:00:08.577146: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 28526336 totalling 27.20MiB
# 2026-02-14 23:00:08.577147: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 33554432 totalling 32.00MiB
# 2026-02-14 23:00:08.577148: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] Sum Total of in-use chunks: 87.11MiB
# 2026-02-14 23:00:08.577150: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1119] Total bytes in pool: 91357184 memory_limit_: 91357184 available bytes: 0 curr_region_allocation_bytes_: 134217728
# 2026-02-14 23:00:08.577152: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1124] Stats:
# Limit:                        91357184
# InUse:                        91344896
# MaxInUse:                     91355904
# NumAllocs:                    15834572
# MaxAllocSize:                 33554432
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2026-02-14 23:00:08.577167: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:512] *******************xxxxxxxxxxxx*************************xxxx********************xxxxxxxxxxxxxxxxx***
# 2026-02-14 23:00:08.582163: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at xla_ops.cc:590 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 10240 bytes. [tf-allocator-allocation-error='']
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/workstation-p/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
df.shape
