# %% [markdown]
# ### Life cycle of dsai project?
# - Data Ingestion
# - Data Preprocessing
# - Feature Engineering
# - Model Training and Evaluation
# - Model Deployment

# %% [markdown]
# ### Key concept in Apache airflow
# - DAG (Directed Acyclic Graph): Collection of task that want to schedule and run.

# %% [markdown]
# ### Why Airflow ?
# - Orchestrating ml pipeline and etl(extract,transform,load) pipeline

# %% [markdown]
# ### Astronomer -> Managing Airflow.

# %% [markdown]
# ### Setup Astronomer for managing Airflow
# - Go to astronomer website and open docs then install astro.

# %% [markdown]
# ### Initializae astro
#
# ```bash
# astro dev init
# ```
#
# ```bash
# astro dev start
# ```

# %% [markdown]
# ### Stop astro
#
# ```bash
# astro dev stop
# ```

# %% [markdown]
# ```bash
# astro deb start --wait 1m
# ```

# %% [markdown]
# ### Deployment
# ```bash
# astro login && astro deploy
# ```
