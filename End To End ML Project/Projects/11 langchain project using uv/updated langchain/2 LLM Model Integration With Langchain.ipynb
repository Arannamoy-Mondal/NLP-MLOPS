# %%
from langchain.chat_models import init_chat_model
from langchain_core.output_parsers import StrOutputParser

# %%
model=init_chat_model("ollama:ministral-3")

# %%
model.invoke("Hello how are you?")
# Out:
# AIMessage(content="Hello! 😊 I'm just a virtual assistant, so I don't have feelings, but I'm here and ready to help you with anything you need! How about you—how are you doing today? Anything fun or interesting on your mind?", additional_kwargs={}, response_metadata={'model': 'ministral-3', 'created_at': '2026-02-16T09:41:00.400005077Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3509731120, 'load_duration': 2190048666, 'prompt_eval_count': 558, 'prompt_eval_duration': 312791013, 'eval_count': 52, 'eval_duration': 940628160, 'logprobs': None, 'model_name': 'ministral-3', 'model_provider': 'ollama'}, id='lc_run--019c65d3-0fb7-7011-8e71-57c3de303dd0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 558, 'output_tokens': 52, 'total_tokens': 610})

# %%
response=model.invoke("Hello how are you?")
response.content
# Out:
# "Hello! 😊 I'm just a virtual assistant, so I don't have feelings, but I'm here and ready to help you with anything you need! How about you—how are you doing today? Anything fun or interesting on your mind?"

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 response=model.invoke("Hello ")
#
# File ~/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/langchain/chat_models/base.py:717, in _ConfigurableModel.invoke(self, input, config, **kwargs)
#     710 @override
#     711 def invoke(
#     712     self,
#    (...)    715     **kwargs: Any,
#     716 ) -> Any:
# --> 717     return self._model(config).invoke(input, config=config, **kwargs)
#
# File ~/anaconda3/envs/conda-env-3-12/lib/python3.12/site-packages/langchain/chat_models/base.py:652, in _ConfigurableModel._model(self, config)
#     650 def _model(self, config: RunnableConfig | None = None) -> Runnable[Any, Any]:
#     651     params = {**self._default_config, **self._model_params(config)}
# --> 652     model = _init_chat_model_helper(**params)
#     653     for name, args, kwargs in self._queued_declarative_operations:
#     654         model = getattr(model, name)(*args, **kwargs)
#
# TypeError: _init_chat_model_helper() missing 1 required positional argument: 'model'
