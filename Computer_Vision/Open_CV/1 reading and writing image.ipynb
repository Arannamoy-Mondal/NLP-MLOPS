# %%
import cv2

# %%
# %ls Images
# Out:
# 'Connection between Scikit Image, Open CV, Pillow, TF,Torch, YOLO.png'*
#  image_new.png

# %%
# read the image
image=cv2.imread("Images/Connection between Scikit Image, Open CV, Pillow, TF,Torch, YOLO.png")

# %%
if image is None:
    print("Could not load the image")
else:
    print("Image loaded successfully.")
# Out:
# Image loaded successfully.

# %%
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
# display the image
# cv2.imshow("image window",image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# write the image
image_new=image+10
cv2.imwrite("Images/image_new.png",image_new)
# Out:
# True
