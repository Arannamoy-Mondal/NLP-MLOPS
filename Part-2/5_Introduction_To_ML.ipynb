# %% [markdown]
# Supervised ML Algorithm: Must be dependent. Regression (Linear regression, Polynomial Regression, Ridge / Lasso Regression , Support Vector Regression (SVR), Decission Tree Regressor, Random Forest Regressr), Classification (Logistic regression, K Nearest Neighbors, Support Vector Machines, Naive Bayes, Decision Trees, Random Forest, Gradient Boosting Algorithms (XGBoost, LightGBM, CatBoost, AdaBoost)).

# %% [markdown]
# Unsupervised ML Algorithm: Custom segmentation

# %% [markdown]
# Reinforcement MLAlgorithm: Reward and Penalty.
