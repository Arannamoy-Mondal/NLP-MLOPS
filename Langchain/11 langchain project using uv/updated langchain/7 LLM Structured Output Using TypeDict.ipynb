# %%
from typing_extensions import TypedDict,Annotated
from langchain.chat_models import init_chat_model

# %%
model=init_chat_model("ollama:llama3.1:8b")

# %%
class MovieDict(TypedDict):
    title:Annotated[str,...,"The title of the movie"]
    year:Annotated[int,...,"The year of the movie"]
    director:Annotated[str,...,"The director of the movie"]
    rating:Annotated[float,...,"The movie's rating out of 10"]

# %%
with_model_output=model.with_structured_output(MovieDict)

# %%
res=with_model_output.invoke("Provide me the details of Inception movie.")
res
# Out:
# {'title': 'Inception',
#  'year': 2010,
#  'director': 'Christopher Nolan',
#  'rating': 8.8}

# %%
print(model.profile)
# Out:
# None
