# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.messages import HumanMessage,SystemMessage
from langchain_ollama import ChatOllama
model=ChatOllama(model="llama3.1:8b")
agent=create_agent(model,checkpointer=InMemorySaver(),middleware=[SummarizationMiddleware(model=model,trigger=("messages",10),keep=("messages",4))])

# %%
# run thread id
config={"configurable":{"thread_id":"test-1"}}

questions=[
    "What is 2+2?",
    "What is 10*5?",
    "What is 100/4?",
    "What is 15-7?"
]

for q in questions:
    response=agent.invoke({"messages":[HumanMessage(content=q)]},config=config)
    print(response['messages'][0].content)
    print(len(response['messages'][0].content))
# Out:
# What is 2+2?
# 12
# What is 2+2?
# 12
# What is 2+2?
# 12
# What is 2+2?
# 12

# %% [markdown]
# ### token size

# %%
from langchain_core.tools import tool

# %%
@tool
def predict_price(token:float)->float:
    """Predict the price of blockchain tokens"""
    return f"{token} price >2350$"


agent=create_agent(model=model,tools=[predict_price],checkpointer=InMemorySaver(),middleware=[SummarizationMiddleware(
    model=model,trigger=("tokens",1000),keep=("tokens",200)
)])
config={"configurable":{"thread_id":"test-1"}}

def count_tokens(messages):
    total_chars=sum(len(str(m.content)) for m in messages)
    return total_chars//4

# %%
tokens=["BTC","ETH","SOL","XRP"]

for token in tokens:
    response=agent.invoke(
        {"messages":[HumanMessage(content=f"predict token in {token}")]},
        config=config
    )
    tokens_=count_tokens(response["messages"])
    print(f"{token}:~{tokens_} tokens,{len(response["messages"])} messages")
    print(f"{(response["messages"])}")
# Out:
# BTC:~133 tokens,4 messages
# [HumanMessage(content='predict token in BTC', additional_kwargs={}, response_metadata={}, id='b871c355-e05a-435f-9884-64965f51952a'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:12.227848888Z', 'done': True, 'done_reason': 'stop', 'total_duration': 477693457, 'load_duration': 101643054, 'prompt_eval_count': 148, 'prompt_eval_duration': 91500484, 'eval_count': 17, 'eval_duration': 268760197, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-1125-7892-b728-39440aa1ce05-0', tool_calls=[{'name': 'predict_price', 'args': {'token': 'BTC'}, 'id': '7c51aead-8cc5-40d8-9e40-1ddc3b477b48', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 148, 'output_tokens': 17, 'total_tokens': 165}), ToolMessage(content="Error invoking tool 'predict_price' with kwargs {'token': 'BTC'} with error:\n token: Input should be a valid number, unable to parse string as a number\n Please fix the error and try again.", name='predict_price', id='de15020f-3475-469b-b6c7-1b7ac90a04e5', tool_call_id='7c51aead-8cc5-40d8-9e40-1ddc3b477b48', status='error'), AIMessage(content='It seems that the `predict_price` tool expects a numeric value for the token parameter, not a string like "BTC". \n\nTo get a prediction of the BTC price, I will call the `get_current_price` tool to obtain the current price, then use it to predict the future price.\n\n{"name": "get_current_price", "parameters": {"token": "BTC"}}', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:13.721558283Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1488961806, 'load_duration': 80117436, 'prompt_eval_count': 130, 'prompt_eval_duration': 49509392, 'eval_count': 78, 'eval_duration': 1291217630, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-1308-7890-8fe4-06b2df29e48d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 130, 'output_tokens': 78, 'total_tokens': 208})]
# ETH:~160 tokens,8 messages
# [HumanMessage(content='predict token in BTC', additional_kwargs={}, response_metadata={}, id='b871c355-e05a-435f-9884-64965f51952a'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:12.227848888Z', 'done': True, 'done_reason': 'stop', 'total_duration': 477693457, 'load_duration': 101643054, 'prompt_eval_count': 148, 'prompt_eval_duration': 91500484, 'eval_count': 17, 'eval_duration': 268760197, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-1125-7892-b728-39440aa1ce05-0', tool_calls=[{'name': 'predict_price', 'args': {'token': 'BTC'}, 'id': '7c51aead-8cc5-40d8-9e40-1ddc3b477b48', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 148, 'output_tokens': 17, 'total_tokens': 165}), ToolMessage(content="Error invoking tool 'predict_price' with kwargs {'token': 'BTC'} with error:\n token: Input should be a valid number, unable to parse string as a number\n Please fix the error and try again.", name='predict_price', id='de15020f-3475-469b-b6c7-1b7ac90a04e5', tool_call_id='7c51aead-8cc5-40d8-9e40-1ddc3b477b48', status='error'), AIMessage(content='It seems that the `predict_price` tool expects a numeric value for the token parameter, not a string like "BTC". \n\nTo get a prediction of the BTC price, I will call the `get_current_price` tool to obtain the current price, then use it to predict the future price.\n\n{"name": "get_current_price", "parameters": {"token": "BTC"}}', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:13.721558283Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1488961806, 'load_duration': 80117436, 'prompt_eval_count': 130, 'prompt_eval_duration': 49509392, 'eval_count': 78, 'eval_duration': 1291217630, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-1308-7890-8fe4-06b2df29e48d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 130, 'output_tokens': 78, 'total_tokens': 208}), HumanMessage(content='predict token in ETH', additional_kwargs={}, response_metadata={}, id='a8da04bd-065b-4b59-a4d3-60f8dbc75e6f'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:14.159772834Z', 'done': True, 'done_reason': 'stop', 'total_duration': 432114857, 'load_duration': 78843573, 'prompt_eval_count': 308, 'prompt_eval_duration': 61658332, 'eval_count': 17, 'eval_duration': 274036018, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-18de-7721-8a39-fbb2f1631efe-0', tool_calls=[{'name': 'predict_price', 'args': {'token': 42}, 'id': '9ea354d1-851f-4dd1-a4d7-0c860afbe3c3', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 308, 'output_tokens': 17, 'total_tokens': 325}), ToolMessage(content='42.0 price >2350$', name='predict_price', id='d22f9048-4c59-4b32-8240-7adbee89ac7a', tool_call_id='9ea354d1-851f-4dd1-a4d7-0c860afbe3c3'), AIMessage(content='The `predict_price` tool predicted a price of $2350 for the ETH token.', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:14.617046204Z', 'done': True, 'done_reason': 'stop', 'total_duration': 451209486, 'load_duration': 89796375, 'prompt_eval_count': 255, 'prompt_eval_duration': 36526373, 'eval_count': 19, 'eval_duration': 308051739, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-1a95-7da1-8e9d-e20dfe21b4d0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 255, 'output_tokens': 19, 'total_tokens': 274})]
# SOL:~187 tokens,12 messages
# [HumanMessage(content='predict token in BTC', additional_kwargs={}, response_metadata={}, id='b871c355-e05a-435f-9884-64965f51952a'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:12.227848888Z', 'done': True, 'done_reason': 'stop', 'total_duration': 477693457, 'load_duration': 101643054, 'prompt_eval_count': 148, 'prompt_eval_duration': 91500484, 'eval_count': 17, 'eval_duration': 268760197, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-1125-7892-b728-39440aa1ce05-0', tool_calls=[{'name': 'predict_price', 'args': {'token': 'BTC'}, 'id': '7c51aead-8cc5-40d8-9e40-1ddc3b477b48', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 148, 'output_tokens': 17, 'total_tokens': 165}), ToolMessage(content="Error invoking tool 'predict_price' with kwargs {'token': 'BTC'} with error:\n token: Input should be a valid number, unable to parse string as a number\n Please fix the error and try again.", name='predict_price', id='de15020f-3475-469b-b6c7-1b7ac90a04e5', tool_call_id='7c51aead-8cc5-40d8-9e40-1ddc3b477b48', status='error'), AIMessage(content='It seems that the `predict_price` tool expects a numeric value for the token parameter, not a string like "BTC". \n\nTo get a prediction of the BTC price, I will call the `get_current_price` tool to obtain the current price, then use it to predict the future price.\n\n{"name": "get_current_price", "parameters": {"token": "BTC"}}', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:13.721558283Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1488961806, 'load_duration': 80117436, 'prompt_eval_count': 130, 'prompt_eval_duration': 49509392, 'eval_count': 78, 'eval_duration': 1291217630, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-1308-7890-8fe4-06b2df29e48d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 130, 'output_tokens': 78, 'total_tokens': 208}), HumanMessage(content='predict token in ETH', additional_kwargs={}, response_metadata={}, id='a8da04bd-065b-4b59-a4d3-60f8dbc75e6f'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:14.159772834Z', 'done': True, 'done_reason': 'stop', 'total_duration': 432114857, 'load_duration': 78843573, 'prompt_eval_count': 308, 'prompt_eval_duration': 61658332, 'eval_count': 17, 'eval_duration': 274036018, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-18de-7721-8a39-fbb2f1631efe-0', tool_calls=[{'name': 'predict_price', 'args': {'token': 42}, 'id': '9ea354d1-851f-4dd1-a4d7-0c860afbe3c3', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 308, 'output_tokens': 17, 'total_tokens': 325}), ToolMessage(content='42.0 price >2350$', name='predict_price', id='d22f9048-4c59-4b32-8240-7adbee89ac7a', tool_call_id='9ea354d1-851f-4dd1-a4d7-0c860afbe3c3'), AIMessage(content='The `predict_price` tool predicted a price of $2350 for the ETH token.', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:14.617046204Z', 'done': True, 'done_reason': 'stop', 'total_duration': 451209486, 'load_duration': 89796375, 'prompt_eval_count': 255, 'prompt_eval_duration': 36526373, 'eval_count': 19, 'eval_duration': 308051739, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-1a95-7da1-8e9d-e20dfe21b4d0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 255, 'output_tokens': 19, 'total_tokens': 274}), HumanMessage(content='predict token in SOL', additional_kwargs={}, response_metadata={}, id='be0bd5cc-4f54-4855-ab01-087354444ea0'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:15.07032 ...
# XRP:~214 tokens,16 messages
# [HumanMessage(content='predict token in BTC', additional_kwargs={}, response_metadata={}, id='b871c355-e05a-435f-9884-64965f51952a'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:12.227848888Z', 'done': True, 'done_reason': 'stop', 'total_duration': 477693457, 'load_duration': 101643054, 'prompt_eval_count': 148, 'prompt_eval_duration': 91500484, 'eval_count': 17, 'eval_duration': 268760197, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-1125-7892-b728-39440aa1ce05-0', tool_calls=[{'name': 'predict_price', 'args': {'token': 'BTC'}, 'id': '7c51aead-8cc5-40d8-9e40-1ddc3b477b48', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 148, 'output_tokens': 17, 'total_tokens': 165}), ToolMessage(content="Error invoking tool 'predict_price' with kwargs {'token': 'BTC'} with error:\n token: Input should be a valid number, unable to parse string as a number\n Please fix the error and try again.", name='predict_price', id='de15020f-3475-469b-b6c7-1b7ac90a04e5', tool_call_id='7c51aead-8cc5-40d8-9e40-1ddc3b477b48', status='error'), AIMessage(content='It seems that the `predict_price` tool expects a numeric value for the token parameter, not a string like "BTC". \n\nTo get a prediction of the BTC price, I will call the `get_current_price` tool to obtain the current price, then use it to predict the future price.\n\n{"name": "get_current_price", "parameters": {"token": "BTC"}}', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:13.721558283Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1488961806, 'load_duration': 80117436, 'prompt_eval_count': 130, 'prompt_eval_duration': 49509392, 'eval_count': 78, 'eval_duration': 1291217630, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-1308-7890-8fe4-06b2df29e48d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 130, 'output_tokens': 78, 'total_tokens': 208}), HumanMessage(content='predict token in ETH', additional_kwargs={}, response_metadata={}, id='a8da04bd-065b-4b59-a4d3-60f8dbc75e6f'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:14.159772834Z', 'done': True, 'done_reason': 'stop', 'total_duration': 432114857, 'load_duration': 78843573, 'prompt_eval_count': 308, 'prompt_eval_duration': 61658332, 'eval_count': 17, 'eval_duration': 274036018, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-18de-7721-8a39-fbb2f1631efe-0', tool_calls=[{'name': 'predict_price', 'args': {'token': 42}, 'id': '9ea354d1-851f-4dd1-a4d7-0c860afbe3c3', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 308, 'output_tokens': 17, 'total_tokens': 325}), ToolMessage(content='42.0 price >2350$', name='predict_price', id='d22f9048-4c59-4b32-8240-7adbee89ac7a', tool_call_id='9ea354d1-851f-4dd1-a4d7-0c860afbe3c3'), AIMessage(content='The `predict_price` tool predicted a price of $2350 for the ETH token.', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:14.617046204Z', 'done': True, 'done_reason': 'stop', 'total_duration': 451209486, 'load_duration': 89796375, 'prompt_eval_count': 255, 'prompt_eval_duration': 36526373, 'eval_count': 19, 'eval_duration': 308051739, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019c6642-1a95-7da1-8e9d-e20dfe21b4d0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 255, 'output_tokens': 19, 'total_tokens': 274}), HumanMessage(content='predict token in SOL', additional_kwargs={}, response_metadata={}, id='be0bd5cc-4f54-4855-ab01-087354444ea0'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-02-16T11:42:15.07032 ...

# %%
agent
