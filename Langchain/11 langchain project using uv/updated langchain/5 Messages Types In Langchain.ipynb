# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
os.environ['LANGCHAIN_API_KEY']=os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_PROJECT']=os.getenv('LANGCHAIN_PROJECT')
os.environ['LANGCHAIN_TRACING_V2']="true"

# %%
model=init_chat_model("ollama:llama3.1:8b")

# %%
model.invoke("Please tell what is artificial intelligence")
# Out:
# AIMessage(content="**Artificial Intelligence (AI)** is a field of computer science that enables machines to think, learn, and act like humans. It's a subfield of computer science that involves creating intelligent machines that can perform tasks that typically require human intelligence, such as:\n\n1. **Learning**: AI systems can be trained on data to improve their performance over time.\n2. **Reasoning**: AI systems can make decisions based on logic, probability, and experience.\n3. **Problem-solving**: AI systems can solve complex problems by analyzing vast amounts of data.\n4. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, or text.\n\nThe goal of AI is to create machines that can perform tasks autonomously, with minimal human intervention, using a combination of algorithms, statistical models, and machine learning techniques.\n\n**Types of Artificial Intelligence:**\n\n1. **Narrow or Weak AI**: Designed to perform specific tasks
# ...

# %%
from langchain.messages import SystemMessage,HumanMessage,AIMessage

# %%
messages=[
    SystemMessage("you are a ml expert"),
    HumanMessage("Write a paragraph on AI")
]

res=model.invoke(messages)

# %%
res.content
# Out:
# "Artificial Intelligence (AI) has revolutionized the way we live and work, with its vast capabilities to learn, reason, and interact with humans. At its core, AI involves developing intelligent machines that can perform tasks autonomously, often surpassing human capabilities in areas such as pattern recognition, natural language processing, and decision-making. From virtual assistants like Siri and Alexa to self-driving cars and personalized product recommendations on e-commerce websites, AI has become an integral part of our daily lives. As a machine learning expert, I'm constantly fascinated by the rapid advancements in AI, including the emergence of deep learning techniques that enable machines to learn from complex data patterns and make predictions with unprecedented accuracy. With its vast potential for innovation and transformation, AI is poised to continue driving progress in industries ranging from healthcare and finance to education and transportation."

# %% [markdown]
# ### Detailed info to the llm through system message

# %%
system_msg=SystemMessage("""You a  ml expert with expertise framework. Always provide code examples and explain your reasoning. Be concise byt through in your explanation""")

messages=[system_msg,HumanMessage("how do I create a RAG system using langchain?")]
res=model.invoke(messages)
print(res.content)
# Out:
# A RAG (Retrieve, Aggregate, Generate) system is a type of conversational AI model that combines retrieval-based and generation-based approaches to answer complex questions.
#
# Here's an example implementation of a basic RAG system using LangChain:
# ```python
# import langchain
# from langchain.agents import ChainAgent
# from langchain.chains.rag import RAGChain
#
# # Define the search engine for retrieving relevant documents
# search_engine = langchain.SearchEngine(
#     index_name="my_index",  # replace with your index name
# )
#
# # Define the aggregation function to combine retrieved text snippets
# def aggregate_snippets(snippets):
#     return "\n".join([snippet["text"] for snippet in snippets])
#
# # Define the generation function to generate a final response
# def generate_response(input_text, aggregated_snippets):
#     return f"Here's a summary of relevant information: {aggregated_snippets}"
#
# ...
