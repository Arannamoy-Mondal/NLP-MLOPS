# %%
from ddgs import DDGS
from langchain_ollama import ChatOllama

# %%
llm=ChatOllama(model="gpt-oss:latest")

# %%
ddgs=DDGS()

# %%
query="Today btc price"

# %%
with ddgs:
    results=ddgs.text(query,max_results=10)

# %%
results
# Out:
# [{'title': 'Bitcoin price today, BTC to USD live price, marketcap and ...',
#   'href': 'https://coinmarketcap.com/currencies/bitcoin/',
#   'body': 'The live Bitcoin price today is $68,786.48 USD with a 24-hour trading volume of $34,401,645,861.04 USD. We update our BTC to USD price in real-time.'},
#  {'title': 'Bitcoin price today , BTC to USD live price , marketcap and... | CoinDesk',
#   'href': 'https://www.coindesk.com/price/bitcoin',
#   'body': 'Live Bitcoin price movements from all markets and BTC market cap, use our charts and see when there is an opportunity to buy or sell.'},
#  {'title': 'Bitcoin Price : BTC Live Price Chart, Market Cap & News Today',
#   'href': 'https://www.coingecko.com/en/coins/bitcoin',
#   'body': 'This represents a -2.65% price decline in the last 24 hours and a -7.52% price decline in the past 7 days. With a circulating supply of 20 Million BTC , Bitcoin is valued at a market cap of $1...'},
#  {'title': 'Bitcoin BTC (BTC-USD) Live Price, News, Chart & Price History ...',
#   'href': 'https://finance.yahoo.com/quote/BTC-USD/?fr=sycsrp_catchall',
#   'body': 'Find the live Bitcoin USD (BTC-USD) price , history, news and other vital information to help with your cryptocurrency trading and investing.'},
#  {'title': 'bitcoin price today: Why is Bitcoin price down today by 2.19% ...',
#   'href': 'https://economictimes.indiatimes.com/news/international/us/why-is-bitcoin-price-down-today-by-2-19-and-will-btc-usd-go-above-68670-to-touch-dream-levels-or-continue-to-drop-bitcoin-fall-price-prediction-analysts-insights-and-market-outlook-explained-what-should-investors-do-now/articleshow/128421128.cms',
#   'body': '19 hours ago · Why is Bitcoin price down today by 2.19% and will BTC USD go above $68,670 to touch dream levels or continue to drop? Bitcoin trades near $68,670 after failing to hold $70,000. Regulation delays, Federal Reserve signals, and resistance levels influence BTC USD direction and investor sentiment.'},
#  {'title': 'Bitcoin (BTC) Price, Real-time Quote & News - Google Finance',
#   'href': 'https://www.google.com/finance/quote/BTC-usd',
#   'body': 'Get the latest Bitcoin (BTC / USD) real-time quote, historical performance, charts, and other cryptocurrency information to help you make more informed trading and investment decisions.'},
#  {'title': 'BTC/USD Price: Convert Bitcoin to United States Dollar ...',
#   'href': 'https://crypto.com/us/price/bitcoin/usd',
#   'body': 'See the latest BTC /USD price and convert Bitcoin to United States Dollar with our instant converter. 1 BTC is currently worth 68,339.12 USD.'},
#  {'title': 'BTC USD — Bitcoin Price and Chart — TradingView',
#   'href': 'https://www.tradingview.com/symbols/BTCUSD/',
#   'body': "Key facts today . From February 12 to 15, Bitcoin's price rose nearly 9%, boosting long futures positions and increasing total open interest from $19.59 billion to $21.47 billion."},
#  {'title': '67,623.1 BTC USDT Spot Trading | OKX',
#   'href': 'https://www.okx.com/trade-spot/btc-usdt',
#   'body': 'OKX - SPOT Trade BTC USDT and other cryptocurrencies on OKX, a top crypto exchange. Modernize your trading experience on our next generation browser-based trading platform.'},
#  {'title': 'Bitcoin Price Today | BTC to USD Live Price , Market Cap & Chart',
#   'href': 'https://www.binance.com/en/price/bitcoin',
#   'body': '1 Bitcoin currently costs $67,606.84, down 2.12% in the last 24h. Convert BTC to USD with our instant crypto converter and view price trends.'}]

# %%
for i, r in enumerate(results, 1):
    print(f"{i}. {r['title']}")
    print(f"   Link: {r['href']}")
    print(f"   Snippet: {r['body']}\n")
# Out:
# 1. Bitcoin price today, BTC to USD live price, marketcap and ...
#    Link: https://coinmarketcap.com/currencies/bitcoin/
#    Snippet: The live Bitcoin price today is $68,786.48 USD with a 24-hour trading volume of $34,401,645,861.04 USD. We update our BTC to USD price in real-time.
#
# 2. Bitcoin price today , BTC to USD live price , marketcap and... | CoinDesk
#    Link: https://www.coindesk.com/price/bitcoin
#    Snippet: Live Bitcoin price movements from all markets and BTC market cap, use our charts and see when there is an opportunity to buy or sell.
#
# 3. Bitcoin Price : BTC Live Price Chart, Market Cap & News Today
#    Link: https://www.coingecko.com/en/coins/bitcoin
#    Snippet: This represents a -2.65% price decline in the last 24 hours and a -7.52% price decline in the past 7 days. With a circulating supply of 20 Million BTC , Bitcoin is valued at a market cap of $1...
#
# 4. Bitcoin BTC (BTC-USD) Live Price, News, Chart & Price History ...
#    Link: https://finance.yahoo.com/quote/BTC-USD/?fr=sycsrp_catchall
#    Snippet: Find the live Bitcoin USD (BTC-USD) price , history, news and other vital information to help with your cryptocurrency trading and investing.
#
# 5. bitcoin price today: Why is Bitcoin price down today by 2.19% ...
#    Link: https://economictimes.indiatimes.com/news/international/us/why-is-bitcoin-price-down-today-by-2-19-and-will-btc-usd-go-above-68670-to-touch-dream-levels-or-continue-to-drop-bitcoin-fall-price-prediction-analysts-insights-and-market-outlook-explained-what-should-investors-do-now/articleshow/128421128.cms
#    Snippet: 19 hours ago · Why is Bitcoin price down today by 2.19% and will BTC USD go above $68,670 to touch dream levels or continue to drop? Bitcoin trades near $68,670 after failing to hold $70,000. Regulation delays, Federal Reserve signals, and resistance levels influence BTC USD direction and investor sentiment.
#
# 6. Bitcoin (BTC) Price, Real-time Quote & News - Google Finance
#    Link: https://www.google.com/finance/quote/BTC-usd
#    Snippet: Get the latest Bitcoin (BTC / USD) real-time quote, historical performance, charts, and other cryptocurrency information to help you make more informed trading and investment decisions.
#
# 7. BTC/USD Price: Convert Bitcoin to United States Dollar ...
#    Link: https://crypto.com/us/price/bitcoin/usd
#    Snippet: See the latest BTC /USD price and convert Bitcoin to United States Dollar with our instant converter. 1 BTC is currently worth 68,339.12 USD.
#
# 8. BTC USD — Bitcoin Price and Chart — TradingView
#    Link: https://www.tradingview.com/symbols/BTCUSD/
#    Snippet: Key facts today . From February 12 to 15, Bitcoin's price rose nearly 9%, boosting long futures positions and increasing total open interest from $19.59 billion to $21.47 billion.
#
# 9. 67,623.1 BTC USDT Spot Trading | OKX
#    Link: https://www.okx.com/trade-spot/btc-usdt
#    Snippet: OKX - SPOT Trade BTC USDT and other cryptocurrencies on OKX, a top crypto exchange. Modernize your trading experience on our next generation browser-based trading platform.
#
# 10. Bitcoin Price Today | BTC to USD Live Price , Market Cap & Chart
#    Link: https://www.binance.com/en/price/bitcoin
#    Snippet: 1 Bitcoin currently costs $67,606.84, down 2.12% in the last 24h. Convert BTC to USD with our instant crypto converter and view price trends.

# %%
results=ddgs.news("BTC")

# %%
results
# Out:
# [{'date': '2026-01-29T07:19:20+00:00',
#   'title': 'Bitcoin Accumulation Surges as Long-Term Holders Average 372,000 BTC Monthly',
#   'body': 'Bitcoin accumulation jumps to 372,000 BTC monthly as CryptoQuant data reveals aggressive long-term holder buying.',
#   'url': 'https://blockonomi.com/bitcoin-accumulation-surges-as-long-term-holders-average-372000-btc-monthly/',
#   'image': 'https://www.bing.com/th?id=OVFT.bAw07zLKtYHrpoXGgqPODC',
#   'source': 'Blockonomi'},
#  {'date': '2026-02-05T07:19:20+00:00',
#   'title': 'Bitcoin weekly RSI echoes mid-2022 bear market as BTC plays liquidity games',
#   'body': 'Bitcoin (BTC) took out long and short positions during Monday as low-volume trading sparked short-term volatility. Key points ...',
#   'url': 'https://www.msn.com/en-us/money/markets/bitcoin-weekly-rsi-echoes-mid-2022-bear-market-as-btc-plays-liquidity-games/ar-AA1WtlxI?ocid=BingNewsVerp',
#   'image': 'https://www.bing.com/th?id=OVFT.pjMT4ST47-8KIcoQbRkJcC',
#   'source': 'Cointelegraph on MSN'},
#  {'date': '2026-02-10T07:19:20+00:00',
#   'title': 'BTC traders wait for $50K bottom: Five things to know in Bitcoin this week',
#   'body': 'Bitcoin (BTC) starts the second week of February still on the defensive after last week’s sharp drawdown, with traders ...',
#   'url': 'https://www.msn.com/en-us/money/markets/btc-traders-wait-for-50k-bottom-five-things-to-know-in-bitcoin-this-week/ar-AA1VYao7?ocid=BingNewsVerp',
#   'image': 'https://www.bing.com/th?id=OVFT.GQotHPa2HJDKd12FjZz9hi',
#   'source': 'Cointelegraph on MSN'},
#  {'date': '2026-02-10T07:19:20+00:00',
#   'title': 'Whales have been buying BTC aggressively during the recent market drop',
#   'body': 'Whales have been buying BTC aggressively during the recent market drop, according to onchain data.',
#   'url': 'https://www.msn.com/en-us/money/markets/whales-have-been-buying-btc-aggressively-during-the-recent-market-drop/ar-AA1VYU5n?ocid=BingNewsVerp',
#   'image': 'https://www.bing.com/th?id=OVFT.9m6QkGBeotUjBEyISbfFVC',
#   'source': 'Cryptopolitan on MSN'},
#  {'date': '2026-02-11T07:19:20+00:00',
#   'title': 'Top bitcoin traders refuse to turn bullish despite BTC’s 14% rebound: Here’s why',
#   'body': 'Bitcoin (BTC) has fluctuated within a tight 8% range over the last four days, consolidating near $69,000 after an abrupt ...',
#   'url': 'https://www.msn.com/en-us/money/economy/top-bitcoin-traders-refuse-to-turn-bullish-despite-btc-s-14-rebound-here-s-why/ar-AA1W5D4r?ocid=BingNewsVerp',
#   'image': 'https://www.bing.com/th?id=OVFT.M8aAEO1nsP4EQn8cgTDIki',
#   'source': 'Cointelegraph on MSN'},
#  {'date': '2026-02-14T07:19:20+00:00',
#   'title': 'Price predictions 2/13: BTC, ETH, BNB, XRP, SOL, DOGE, BCH, HYPE, ADA, XMR',
#   'body': 'Bitcoin (BTC) has risen above $68,500, as buyers attempt to form a higher low near $65,000. According to Glassnode, BTC is ...',
#   'url': 'https://www.msn.com/en-us/money/general/price-predictions-2-13-btc-eth-bnb-xrp-sol-doge-bch-hype-ada-xmr/ar-AA1WjucT?ocid=BingNewsVerp',
#   'image': 'https://www.bing.com/th?id=OVFT.ie6mhOnDKteIGqm2m2OQFi',
#   'source': 'Cointelegraph on MSN'},
#  {'date': '2026-02-16T16:35:00+00:00',
#   'title': 'Trump Family-Backed American Bitcoin Keeps Stacking Bitcoin, Holdings Pass 6,000 BTC',
#   'body': 'Trump family-backed American Bitcoin Corp. (ABTC) has pushed its Bitcoin reserves above the 6,000 BTC mark, building one of the largest corporate treasuries in the public market and placing the firm among the top 20 listed Bitcoin holders worldwide.',
#   'url': 'https://bitcoinmagazine.com/news/american-bitcoin-keeps-stacking-bitcoin',
#   'image': None,
#   'source': 'Bitcoin Magazine'},
#  {'date': '2026-02-11T15:11:00+00:00',
#   'title': 'DDC Enterprise ($DDC) Adds 100 Bitcoin, Treasury Holdings Reach 1,988 BTC',
#   'body': 'DDC Enterprise says it bought another 100 bitcoin, lifting its stash to 1,988 BTC as it pushes ahead with an aggressive, long-term treasury strategy despite bitcoin trading around $67,000.',
#   'url': 'https://bitcoinmagazine.com/news/ddc-enterprise-ddc-adds-100-bitcoin',
#   'image': 'https://bitcoinmagazine.com/wp-content/uploads/2026/02/DDC-Enterprise-DDC-Adds-100-Bitcoin-Treasury-Holdings-Reach-1988-BTC-696x392.jpg',
#   'source': 'Bitcoin Magazine'},
#  {'date': '2026-02-15T06:24:00+00:00',
#   'title': 'Bitcoin (BTC) Surges Past $70K as Inflation Cools, ETFs Steady',
#   'body': "Bitcoin (BTC) rebounds above $70K as US CPI lifts Fed rate cut bets. ETF flows, Senate crypto bill hopes, and key data now influence BTC's short-term outlook.",
#   'url': 'https://www.fxempire.com/forecasts/article/bitcoin-btc-surges-past-70k-as-inflation-cools-etfs-steady-1579605',
#   'image': None,
#   'source': 'FX Empire'},
#  {'date': '2026-02-06T06:47:00+00:00',
#   'title': "How Low Can Bitcoin Fall This Month? Prediction Markets See BTC Touching A Level Which Michael Burry Says Will Make Miners 'Bankrupt'",
#   'body': "Over the past month, Bitcoin (CRYPTO: BTC), the world's largest cryptocurrency, has seen a notable slide in price and market sentiment, declining nearly 30%, reversing",
#   'url': 'https://www.benzinga.com/markets/prediction-markets/26/02/50438397/how-low-can-bitcoin-fall-this-month-prediction-markets-see-btc-touching-a-level-which-michael-burry-says-will-make-miners-bankrupt',
#   'image': 'https://cdn.benzinga.com/files/images/story/2026/02/06/Golden-Bitcoin-Coin-Is-In-Red-And-Blue-S.jpeg?width=1200&height=800&fit=crop',
#   'source': 'Benzinga'}]
