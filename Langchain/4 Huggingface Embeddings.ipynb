# %%
# %uv pip install sentence_transformers langchain_huggingface tf-keras

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['HF_TOKEN']=os.getenv("HF_TOKEN")

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
huggingface_embedding=HuggingFaceEmbeddings(model="all-MiniLM-L6-v2")

# %%
text="This is  a text doc"

# %%
query_result=huggingface_embedding.embed_query(text)

# %%
len(query_result)
# Out:
# 384

# %%
query_result[0]
# Out:
# -0.03237787261605263
