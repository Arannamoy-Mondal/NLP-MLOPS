# %% [markdown]
# ### LangChain Expression Language

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['LANGCHAIN_API_KEY']=os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_PROJECT']=os.getenv('LANGCHAIN_PROJECT')
os.environ['LANGCHAIN_TRACING_V2']="true"

# %%
from langchain_ollama import ChatOllama

# %%
llm=ChatOllama(model="gemma3:4b")

# %%
from langchain_core.messages import HumanMessage,SystemMessage

# %%
messages=[
    SystemMessage(content="translate the following from English to French"),
    HumanMessage(content="Hello how are you?")
]

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
# using LCEL
parser=StrOutputParser()
chain=llm|parser

# %%
result=chain.invoke(messages)

# %%
result
# Out:
# 'Here are a few options for translating "Hello how are you?" into French, depending on the level of formality:\n\n*   **Formal:** Bonjour, comment allez-vous ?\n*   **Informal:** Salut, comment vas-tu ?\n\n**Explanation:**\n\n*   **Bonjour** (formal) / **Salut** (informal) - Hello\n*   **Comment allez-vous ?** (formal) - How are you? (used with people you don\'t know well, or those older than you)\n*   **Comment vas-tu ?** (informal) - How are you? (used with friends, family, or people your age)\n\nWould you like me to give you a more specific translation based on the context?'
