# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
ollama_embedding=OllamaEmbeddings(
     model="phi4:latest"
)
# Out:
# /tmp/ipykernel_493434/2674416319.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   ollama_embedding=OllamaEmbeddings(

# %%
r1=ollama_embedding.embed_documents(
    [
        "Tell me a joke",
        "Explain me about NVIDIA"
    ]
)

# %%
result=ollama_embedding.embed_query("Explain me about NVIDIA")
