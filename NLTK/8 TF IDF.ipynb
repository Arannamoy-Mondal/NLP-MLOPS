# %% [markdown]
# ### TF = Term Frequency
#
# $$TF=\frac{\text{word count in doc}}{\text{total words in doc}}$$
#
#
#
#
# 	​

# %% [markdown]
# ## IDF = Inverse Document Frequency
# $$IDF=\log (\frac{\text{Total Documents}}{\text{Number of Documents containing the wordTotal Documents}})$$

# %% [markdown]
# $$TF-IDF=TF×IDF$$
