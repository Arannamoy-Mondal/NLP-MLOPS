# %% [markdown]
# #### Key concept in Apache airflow
# - DAG (Directed Acyclic Graph): Collection of task that want to schedule and run.
# #### Why Airflow ?
# - Orchestrating ml pipeline and etl(extract,transform,load) pipeline
#
# #### Astro installation doc
# ```bash
# https://www.astronomer.io/docs/astro/cli/install-cli
# ```

# %% [markdown]
# ### Initializae astro
# ```bash
# astro dev init
# ```
#
# ### Start astro
# ```bash
# astro dev start
# ```
#
# - Default user and password: admin

# %% [markdown]
# ### Stop astro
#
# ```bash
# astro dev stop
# ```
# ```bash
# astro deb start --wait 1m
# ```
#
#
# ### Deployment
# ```bash
# astro login && astro deploy
# ```
