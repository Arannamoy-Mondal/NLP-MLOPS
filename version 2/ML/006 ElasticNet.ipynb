# %% [markdown]
# ##### L1 and L2
# - Coefficient can be 0

# %%
from sklearn.linear_model import ElasticNet
lr=ElasticNet()
lr.fit(X_train,y_train)
from sklearn.metrics import r2_score
score=r2_score(y_test,lr.predict(X_test))
score
